# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('datasets')
# Out:
# Mounted at datasets

# %%
df = pd.read_csv('datasets/MyDrive/datasets/bl_property_data_new.csv')
# Out:
# <ipython-input-5-72dd85d1cde4>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('datasets/MyDrive/datasets/bl_property_data_new.csv')

# %%
df.head()
# Out:
#      area building_type building_nature  \
# 0  1185.0     Apartment     Residential
# 1  2464.0     Apartment     Residential
# 2  1140.0     Apartment     Residential
# 3  1920.0     Apartment     Residential
# 4  1445.0     Apartment     Residential
#
#                                            image_url  num_bath_rooms  \
# 0  https://images-cdn.bproperty.com/thumbnails/15...             0.0
# 1  https://images-cdn.bproperty.com/thumbnails/15...             4.0
# 2  https://images-cdn.bproperty.com/thumbnails/15...             0.0
# 3  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 4  https://images-cdn.bproperty.com/thumbnails/15...             3.0
#
#    num_bed_rooms       price  \
# 0            3.0   6100000.0
# 1            3.0  28900000.0
# 2            3.0   7500000.0
# 3            3.0  20000000.0
# 4            3.0  10800000.0
#
#                                 property_description  \
# 0  Grab This 1185 Sq Ft Beautiful Flat Is Vacant ...
# ...

# %%
df.isnull().sum()
# Out:
# area                                         0
# building_type                                0
# building_nature                              0
# image_url                                16436
# num_bath_rooms                               0
# num_bed_rooms                                0
# price                                        0
# property_description                     14672
# property_overview                        15192
# property_url                                22
# purpose                                      0
# city                                         0
# locality                                     0
# address                                   5177
# id                                           0
# relaxation_amenity_count                     0
# security_amenity_count                       0
# maintenance_or_cleaning_amenity_count        0
# social_amenity_count                         0
# expendable_amenity_count                     0
# ...

# %%
features = ['area','building_type','building_nature','image_url','num_bath_rooms','num_bed_rooms','price','property_description','property_overview','property_url','purpose','city','locality','division','zone','id']

# %%
# We took features which are required for the recommendation system
df_1 = df[features]

# %%
df_1.head()
# Out:
#      area building_type building_nature  \
# 0  1185.0     Apartment     Residential
# 1  2464.0     Apartment     Residential
# 2  1140.0     Apartment     Residential
# 3  1920.0     Apartment     Residential
# 4  1445.0     Apartment     Residential
#
#                                            image_url  num_bath_rooms  \
# 0  https://images-cdn.bproperty.com/thumbnails/15...             0.0
# 1  https://images-cdn.bproperty.com/thumbnails/15...             4.0
# 2  https://images-cdn.bproperty.com/thumbnails/15...             0.0
# 3  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 4  https://images-cdn.bproperty.com/thumbnails/15...             3.0
#
#    num_bed_rooms       price  \
# 0            3.0   6100000.0
# 1            3.0  28900000.0
# 2            3.0   7500000.0
# 3            3.0  20000000.0
# 4            3.0  10800000.0
#
#                                 property_description  \
# 0  Grab This 1185 Sq Ft Beautiful Flat Is Vacant ...
# ...

# %%
df_1.isnull().sum()
# Out:
# area                        0
# building_type               0
# building_nature             0
# image_url               16436
# num_bath_rooms              0
# num_bed_rooms               0
# price                       0
# property_description    14672
# property_overview       15192
# property_url               22
# purpose                     0
# city                        0
# locality                    0
# division                    3
# zone                       85
# id                          0
# dtype: int64

# %%
df_2 = df_1.dropna(subset=['property_description','property_overview'])

# %%
df_2.isnull().sum()
# Out:
# area                       0
# building_type              0
# building_nature            0
# image_url               1244
# num_bath_rooms             0
# num_bed_rooms              0
# price                      0
# property_description       0
# property_overview          0
# property_url               0
# purpose                    0
# city                       0
# locality                   0
# division                   0
# zone                      23
# id                         0
# dtype: int64

# %%
df_3 = df_2.dropna(subset=['image_url','zone'])

# %%
df_3.isnull().sum()
# Out:
# area                    0
# building_type           0
# building_nature         0
# image_url               0
# num_bath_rooms          0
# num_bed_rooms           0
# price                   0
# property_description    0
# property_overview       0
# property_url            0
# purpose                 0
# city                    0
# locality                0
# division                0
# zone                    0
# id                      0
# dtype: int64

# %%
df_3['building_type'].unique()
# Out:
# array(['Apartment', 'Shop', 'Floor', 'Office', 'Building',
#        'Residential Plot', 'Duplex', 'Commercial Plot', 'Warehouse',
#        'Factory'], dtype=object)

# %%
df_3['building_nature'].unique()
# Out:
# array(['Residential', 'Commercial'], dtype=object)

# %%
df_residential = df_3.loc[df['building_nature'] == 'Residential']

# %%
df_commercial = df_3.loc[df['building_nature'] == 'Commercial']

# %%
print('Number of records in the dataframe',len(df_3))
# Out:
# Number of records in the dataframe 17244

# %%
print('Number of records in Residential dataframe',len(df_residential))
# Out:
# Number of records in Residential dataframe 13335

# %%
print('Number of records in Commercial DataFrame',len(df_commercial))
# Out:
# Number of records in Commercial DataFrame 3909

# %%
df_residential.head()
# Out:
#      area building_type building_nature  \
# 0  1185.0     Apartment     Residential
# 1  2464.0     Apartment     Residential
# 2  1140.0     Apartment     Residential
# 3  1920.0     Apartment     Residential
# 4  1445.0     Apartment     Residential
#
#                                            image_url  num_bath_rooms  \
# 0  https://images-cdn.bproperty.com/thumbnails/15...             0.0
# 1  https://images-cdn.bproperty.com/thumbnails/15...             4.0
# 2  https://images-cdn.bproperty.com/thumbnails/15...             0.0
# 3  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 4  https://images-cdn.bproperty.com/thumbnails/15...             3.0
#
#    num_bed_rooms       price  \
# 0            3.0   6100000.0
# 1            3.0  28900000.0
# 2            3.0   7500000.0
# 3            3.0  20000000.0
# 4            3.0  10800000.0
#
#                                 property_description  \
# 0  Grab This 1185 Sq Ft Beautiful Flat Is Vacant ...
# ...

# %%
df_residential['city'].unique()
# Out:
# array(['Dhaka', 'Chattogram', 'Narayanganj City', 'Gazipur', 'Sylhet'],
#       dtype=object)

# %%
df_commercial['city'].unique()
# Out:
# array(['Dhaka', 'Chattogram', 'Sylhet', 'Gazipur', 'Narayanganj City'],
#       dtype=object)

# %%
df_residential['building_type'].unique()
# Out:
# array(['Apartment', 'Building', 'Residential Plot', 'Duplex'],
#       dtype=object)

# %%
df_commercial['building_type'].unique()
# Out:
# array(['Shop', 'Floor', 'Office', 'Building', 'Apartment',
#        'Commercial Plot', 'Warehouse', 'Duplex', 'Factory'], dtype=object)

# %%
df_residential.drop(df_residential[df_residential['num_bed_rooms'] == 0 ].index, inplace = True)
# Out:
# <ipython-input-28-a095d56a38e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residential.drop(df_residential[df_residential['num_bed_rooms'] == 0 ].index, inplace = True)

# %%
df_residential['num_bed_rooms'].unique()
# Out:
# array([ 3.,  2.,  4., 21., 20.,  5.,  7.,  1.,  6., 19., 24., 33., 56.,
#        18., 10., 13., 48., 12., 60., 40., 29., 23., 17., 14.,  8., 50.,
#        75., 42., 16., 36., 15., 25., 22., 46., 30., 11., 32., 94.])

# %%
df_residential.drop(df_residential[df_residential['num_bath_rooms'] == 0 ].index, inplace = True)
# Out:
# <ipython-input-30-d85a7f92aa4c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residential.drop(df_residential[df_residential['num_bath_rooms'] == 0 ].index, inplace = True)

# %%
df_residential['num_bath_rooms'].unique()
# Out:
# array([ 4.,  3.,  2., 10.,  5.,  8.,  1.,  7.,  6.,  9.])

# %%
df_residential.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5669 entries, 1 to 17281
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   area                  5669 non-null   float64
#  1   building_type         5669 non-null   object
#  2   building_nature       5669 non-null   object
#  3   image_url             5669 non-null   object
#  4   num_bath_rooms        5669 non-null   float64
#  5   num_bed_rooms         5669 non-null   float64
#  6   price                 5669 non-null   float64
#  7   property_description  5669 non-null   object
#  8   property_overview     5669 non-null   object
#  9   property_url          5669 non-null   object
#  10  purpose               5669 non-null   object
#  11  city                  5669 non-null   object
#  12  locality              5669 non-null   object
#  13  division              5669 non-null   object
#  14  zone                  5669 non-null   object
# ...

# %%
df_residential['describe_2'] = "This "+df_residential['area'].sum().astype(int).astype(str)+" square ft Area of the "+ df_residential['purpose']+" "+df_residential['building_type']+" is a residential property with "+df_residential['num_bed_rooms'].sum().astype(int).astype(str)+" bedrooms and "+ df_residential['num_bath_rooms'].sum().astype(int).astype(str)+" baths and priced at BDT "+df_residential['price'].sum().astype(int).astype(str) +" in "+df_residential['locality']+" and zone in "+df_residential['zone'] + " city is "+df_residential['city'] +" . "
# Out:
# <ipython-input-79-2287c2642682>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_residential['describe_2'] = "This "+df_residential['area'].sum().astype(int).astype(str)+" square ft Area of the "+ df_residential['purpose']+" "+df_residential['building_type']+" is a residential property with "+df_residential['num_bed_rooms'].sum().astype(int).astype(str)+" bedrooms and "+ df_residential['num_bath_rooms'].sum().astype(int).astype(str)+" baths and priced at BDT "+df_residential['price'].sum().astype(int).astype(str) +" in "+df_residential['locality']+" and zone in "+df_residential['zone'] + " city is "+df_residential['city'] +" . "

# %%
df_residential.head()
# Out:
#      area building_type building_nature  \
# 1  2464.0     Apartment     Residential
# 3  1920.0     Apartment     Residential
# 4  1445.0     Apartment     Residential
# 6  2468.0     Apartment     Residential
# 7  1475.0     Apartment     Residential
#
#                                            image_url  num_bath_rooms  \
# 1  https://images-cdn.bproperty.com/thumbnails/15...             4.0
# 3  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 4  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 6  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 7  https://images-cdn.bproperty.com/thumbnails/15...             3.0
#
#    num_bed_rooms       price  \
# 1            3.0  28900000.0
# 3            3.0  20000000.0
# 4            3.0  10800000.0
# 6            3.0  36500000.0
# 7            3.0  10500000.0
#
#                                 property_description  \
# 1  A Vibrant 2464 Sq Ft Residential Flat For Sale...
# ...

# %%
df_commercial['describe_2'] = "This "+df_commercial['area'].sum().astype(int).astype(str)+" Sq ft area of the "+df_commercial['purpose']+" "+df_commercial['building_type']+" in a commercial property and priced at BDT "+df_commercial['price'].sum().astype(int).astype(str)+" in "+df_commercial['locality']+" zone in "+df_commercial['zone']+ " city is "+df_commercial['city'] +" . "
# Out:
# <ipython-input-88-474a1ec7c254>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_commercial['describe_2'] = "This "+df_commercial['area'].sum().astype(int).astype(str)+" Sq ft area of the "+df_commercial['purpose']+" "+df_commercial['building_type']+" in a commercial property and priced at BDT "+df_commercial['price'].sum().astype(int).astype(str)+" in "+df_commercial['locality']+" zone in "+df_commercial['zone']+ " city is "+df_commercial['city'] +" . "

# %%
df_commercial.head()
# Out:
#       area building_type building_nature  \
# 13  1220.0          Shop      Commercial
# 18  3955.0         Floor      Commercial
# 27   275.0        Office      Commercial
# 29  1650.0        Office      Commercial
# 30   456.0          Shop      Commercial
#
#                                             image_url  num_bath_rooms  \
# 13  https://images-cdn.bproperty.com/thumbnails/10...             0.0
# 18  https://images-cdn.bproperty.com/thumbnails/15...             0.0
# 27  https://images-cdn.bproperty.com/thumbnails/15...             0.0
# 29  https://images-cdn.bproperty.com/thumbnails/14...             0.0
# 30  https://images-cdn.bproperty.com/thumbnails/10...             0.0
#
#     num_bed_rooms       price  \
# 13            0.0  15000000.0
# 18            0.0    500000.0
# 27            0.0   9625000.0
# 29            0.0  10000000.0
# 30            0.0   6000000.0
#
#                                  property_description  \
# ...

# %%
df_commercial['describe_2'].iloc[0]
# Out:
# 'This 13513537 Sq ft area of the Sale Shop in a commercial property and priced at BDT 20376074780 in Dhanmondi zone in Dhanmondi city is Dhaka . '

# %%
frames = [df_residential,df_commercial]

# %%
df_result = pd.concat(frames)

# %%
len(df_result)
# Out:
# 9578

# %%
df_result['recommend_text'] = df_result['describe_2']+" "+df_result['property_description']+df_result['property_overview']

# %%
df_result.to_csv('bl_property_processed.csv',index=False)

# %%
df_processed = pd.read_csv('datasets/MyDrive/datasets/bl_property_processed.csv')

# %%
df_processed.head()
# Out:
#      area building_type building_nature  \
# 0  2464.0     Apartment     Residential
# 1  1920.0     Apartment     Residential
# 2  1445.0     Apartment     Residential
# 3  2468.0     Apartment     Residential
# 4  1475.0     Apartment     Residential
#
#                                            image_url  num_bath_rooms  \
# 0  https://images-cdn.bproperty.com/thumbnails/15...             4.0
# 1  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 2  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 3  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 4  https://images-cdn.bproperty.com/thumbnails/15...             3.0
#
#    num_bed_rooms       price  \
# 0            3.0  28900000.0
# 1            3.0  20000000.0
# 2            3.0  10800000.0
# 3            3.0  36500000.0
# 4            3.0  10500000.0
#
#                                 property_description  \
# 0  A Vibrant 2464 Sq Ft Residential Flat For Sale...
# ...

# %%
# !!pip install -U sentence-transformers
# Out:
# ['Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/',
#  'Collecting sentence-transformers',
#  '  Downloading sentence-transformers-2.2.2.tar.gz (85 kB)',
#  '\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/86.0 kB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b86.0/86.0 kB\x1b \x1b3.0 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h  Preparing metadata (setup.py) ... \x1b[?25l\x1b[?25hdone',
#  'Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers)',
#  '  Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)',
#  '\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/7.1 MB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K     \x1b━━\x1b\x1b╸\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.5/7.1 MB\x1b \x1b14.6 MB/s\x1b eta \x1b0:00:01\x1b',
# ...

# %%
df_processed['recommend_text'][0]
# Out:
# 'This 8703254 square ft Area of the Sale Apartment is a residential property with 17520 bedrooms and 16825 baths and priced at BDT 45154079350 in Dhanmondi and zone in Dhanmondi city is Dhaka .  A Vibrant 2464 Sq Ft Residential Flat For Sale In ShukrabadReady to move in somewhere with everything nearby? This apartment bears all the necessary facilities that you look for in a flat and more. There are many facilities in the flat that are required to live at ease. Utility supplies are always available and security services are present at all times for ensuring the safety of the inhabitants. The washroom and kitchen come with all the modern fixtures.  The flat is well secured with the availability of all types of utilities.  Don’t miss this remunerative offer and we are just a call away to close the deal for you!'

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
model = SentenceTransformer('paraphrase-distilroberta-base-v1')

# %%
import os 
import numpy as np

descriptions = df_processed['recommend_text'].tolist()
embeddings_file = 'property_recommend.npy'

# %%
if not os.path.exists(embeddings_file):
    description_embeddings = model.encode(descriptions)
    np.save(embeddings_file, description_embeddings)
else:
    # Load the saved embeddings
    description_embeddings = np.load(embeddings_file)

# %%
# Define the query and calculate its embedding
query = "Provide 1000 sq feet apartments with 2 beds priced at 500,000 in Gulshan?"
query_embedding = model.encode([query])

# %%
# Compute cosine similarity between the query embedding and all description embeddings
similarities = cosine_similarity(query_embedding, description_embeddings)

# %%
# Find the indices of the top 5 most similar descriptions
top_n = 5
top_n_indices = similarities[0].argsort()[-top_n:][::-1]
print(top_n_indices)
# Out:
# [5659 3031 5586 5589 5512]

# %%
# Print the top 5 most similar product descriptions
# Print the top 5 most similar product descriptions
for index in top_n_indices:
    print(f"Property ID: {df_processed.iloc[index]}")
# Out:
# Property ID: area                                                               5000.0
# building_type                                                   Apartment
# building_nature                                               Residential
# image_url               https://images-cdn.bproperty.com/thumbnails/97...
# num_bath_rooms                                                        4.0
# num_bed_rooms                                                         4.0
# price                                                          80000000.0
# property_description    A nicely constructed flat of 5000 SQ FT can be...
# property_overview       The vacant flat of 5000 Square Feet comes with...
# property_url            https://www.bproperty.com/en/property/details-...
# purpose                                                              Sale
# city                                                                Dhaka
# ...
