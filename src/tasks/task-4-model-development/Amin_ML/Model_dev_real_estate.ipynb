# %%
# Library to suppress warnings or deprecation notes 
import warnings
warnings.filterwarnings('ignore')

# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Libraries to split data, impute missing values, and scale values
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# Libraries to import decision tree classifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import StackingClassifier

# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/My Drive/no_outlier_df.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29813 entries, 0 to 29812
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   area                                   29813 non-null  float64
#  1   building_type                          29813 non-null  object
#  2   building_nature                        29813 non-null  object
#  3   image_url                              16299 non-null  object
#  4   num_bath_rooms                         29813 non-null  float64
#  5   num_bed_rooms                          29813 non-null  float64
#  6   price                                  29813 non-null  float64
#  7   property_description                   16557 non-null  object
#  8   property_overview                      16321 non-null  object
#  9   property_url                           29794 non-null  object
#  10  purpose                                29813 non-null  object
#  11  city                                   29813 non-null  object
#  12  locality                               29813 non-null  object
#  13  address                                25133 non-null  object
#  14  id                                     29813 non-null  object
#  15  relaxation_amenity_count               29813 non-null  int64
#  16  security_amenity_count                 29813 non-null  int64
#  17  maintenance_or_cleaning_amenity_count  29813 non-null  int64
#  18  social_amenity_count                   29813 non-null  int64
#  19  expendable_amenity_count               29813 non-null  int64
#  20  service_staff_amenity_count            29813 non-null  int64
#  21  unclassify_amenity_count               29813 non-null  int64
#  22  division                               29812 non-null  object
#  23  zone                                   29733 non-null  object
# dtypes: float64(4), int64(7), object(13)
# memory usage: 5.5+ MB

# %%
df.head(5)
# Out:
#      area building_type building_nature  \
# 0  1100.0     Apartment     Residential
# 1  1300.0     Apartment     Residential
# 2  1500.0     Apartment     Residential
# 3  1350.0     Apartment     Residential
# 4  1825.0     Apartment     Residential
#
#                                            image_url  num_bath_rooms  \
# 0  https://images-cdn.bproperty.com/thumbnails/80...             3.0
# 1  https://images-cdn.bproperty.com/thumbnails/13...             3.0
# 2  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 3  https://images-cdn.bproperty.com/thumbnails/15...             3.0
# 4  https://images-cdn.bproperty.com/thumbnails/15...             4.0
#
#    num_bed_rooms    price                               property_description  \
# 0            3.0  22000.0  1150 Square Feet Apartment For Rent In Mohamma...
# 1            3.0  40000.0  Grab This Lovely Flat For Rent In Bashundhara ...
# 2            3.0  35000.0  1500 Square Feet Apartment With Necessary Resi...
# 3            3.0  20000.0  Wow! This 1350 Sq Ft Apartment For Rent In Bas...
# 4            3.0  60000.0  This 1825 Sq. Ft Apartment Will Ensure Your Go...
#
#                                    property_overview  \
# 0  The apartment of 1100  Square Feet is located ...
# 1  This lovely apartment is located in a great lo...
# 2  Make this beautiful 1,500 Sft apartment in Utt...
# 3  In a very busy city like Dhaka, everyone tranc...
# 4  In a very busy city like Dhaka, everyone tranc...
#
#                                         property_url  ...               id  \
# 0  https://www.bproperty.com/en/property/details-...  ...  bproperty-14087
# 1  https://www.bproperty.com/en/property/details-...  ...  bproperty-14091
# 2  https://www.bproperty.com/en/property/details-...  ...  bproperty-14092
# 3  https://www.bproperty.com/en/property/details-...  ...  bproperty-14093
# 4  https://www.bproperty.com/en/property/details-...  ...  bproperty-14094
#
#   relaxation_amenity_count security_amenity_count  \
# 0                        0                      2
# 1                        0                      2
# 2                        0                      1
# 3                        0                      0
# 4                        0                      2
#
#   maintenance_or_cleaning_amenity_count social_amenity_count  \
# 0                                     2                    0
# 1                                     2                    0
# 2                                     3                    2
# 3                                     0                    0
# 4                                     1                    0
#
#    expendable_amenity_count  service_staff_amenity_count  \
# 0                         5                            0
# 1                         4                            0
# 2                         2                            0
# 3                         4                            0
# 4                         3                            0
#
#    unclassify_amenity_count  division             zone
# 0                         4     Dhaka      Mohammadpur
# 1                         5     Dhaka  Bashundhara R/A
# 2                         4     Dhaka           Uttara
# 3                         3     Dhaka  Bashundhara R/A
# 4                         4     Dhaka           Uttara
#
# [5 rows x 24 columns]

# %%
df1 = df.drop(['area','property_url', 'image_url', 'address' ,'id', 'property_description', 'property_overview'], axis = 1)

# %%
df1.shape
# Out:
# (29813, 17)

# %%
df1.head(5)
# Out:
#   building_type building_nature  num_bath_rooms  num_bed_rooms    price  \
# 0     Apartment     Residential             3.0            3.0  22000.0
# 1     Apartment     Residential             3.0            3.0  40000.0
# 2     Apartment     Residential             3.0            3.0  35000.0
# 3     Apartment     Residential             3.0            3.0  20000.0
# 4     Apartment     Residential             4.0            3.0  60000.0
#
#   purpose   city         locality  relaxation_amenity_count  \
# 0    Rent  Dhaka      Mohammadpur                         0
# 1    Rent  Dhaka  Bashundhara R-A                         0
# 2    Rent  Dhaka           Uttara                         0
# 3    Rent  Dhaka  Bashundhara R-A                         0
# 4    Rent  Dhaka           Uttara                         0
#
#    security_amenity_count  maintenance_or_cleaning_amenity_count  \
# 0                       2                                      2
# 1                       2                                      2
# 2                       1                                      3
# 3                       0                                      0
# 4                       2                                      1
#
#    social_amenity_count  expendable_amenity_count  \
# 0                     0                         5
# 1                     0                         4
# 2                     2                         2
# 3                     0                         4
# 4                     0                         3
#
#    service_staff_amenity_count  unclassify_amenity_count division  \
# 0                            0                         4    Dhaka
# 1                            0                         5    Dhaka
# 2                            0                         4    Dhaka
# 3                            0                         3    Dhaka
# 4                            0                         4    Dhaka
#
#               zone
# 0      Mohammadpur
# 1  Bashundhara R/A
# 2           Uttara
# 3  Bashundhara R/A
# 4           Uttara

# %% [markdown]
# ### Data Pre-processing

# %%
# Calculate the percentage of missing values in each column
missing_percentage = df1.isnull().sum() / len(df1) * 100

# Create a new dataframe to store the results
missing_data = pd.DataFrame({'Variable': df1.columns, 'MissingPercentage': missing_percentage})

# Sort the dataframe by the missing percentage in descending order
missing_data.sort_values('MissingPercentage', ascending=False, inplace=True)

# Print the missing data summary
print(missing_data)
# Out:
#                                                                     Variable  \
# zone                                                                    zone
# division                                                            division
# security_amenity_count                                security_amenity_count
# unclassify_amenity_count                            unclassify_amenity_count
# service_staff_amenity_count                      service_staff_amenity_count
# expendable_amenity_count                            expendable_amenity_count
# social_amenity_count                                    social_amenity_count
# maintenance_or_cleaning_amenity_count  maintenance_or_cleaning_amenity_count
# building_type                                                  building_type
# building_nature                                              building_nature
# locality                                                            locality
# city                                                                    city
# purpose                                                              purpose
# price                                                                  price
# num_bed_rooms                                                  num_bed_rooms
# num_bath_rooms                                                num_bath_rooms
# relaxation_amenity_count                            relaxation_amenity_count
#
#                                        MissingPercentage
# zone                                            0.268339
# division                                        0.003354
# security_amenity_count                          0.000000
# unclassify_amenity_count                        0.000000
# service_staff_amenity_count                     0.000000
# expendable_amenity_count                        0.000000
# social_amenity_count                            0.000000
# maintenance_or_cleaning_amenity_count           0.000000
# building_type                                   0.000000
# building_nature                                 0.000000
# locality                                        0.000000
# city                                            0.000000
# purpose                                         0.000000
# price                                           0.000000
# num_bed_rooms                                   0.000000
# num_bath_rooms                                  0.000000
# relaxation_amenity_count                        0.000000

# %%
df1['purpose'].unique()
# Out:
# array(['Rent', 'Sale'], dtype=object)

# %%
df1['building_type'].unique()
# Out:
# array(['Apartment', 'Duplex', 'House', 'Residential Plot', 'Building',
#        'Others', 'Commercial Plot', 'Shop', 'Office', 'Floor',
#        'Warehouse', 'Factory'], dtype=object)

# %%
## feature engineering 

## ratio of bedrooms to bathrooms 

# df1['bedroom_to_bathroom_ratio'] = df1['num_bed_rooms'] / df1['num_bath_rooms']

# %%
## Total Amenity Count

# df1['total_amenity_count'] = df1['relaxation_amenity_count'] + df1['security_amenity_count'] + df1['maintenance_or_cleaning_amenity_count'] + df1['social_amenity_count'] + df1['expendable_amenity_count'] + df1['service_staff_amenity_count'] + df1['unclassify_amenity_count']

# %%
## Amenity Category Ratios

## df1['relaxation_ratio'] = df1['relaxation_amenity_count'] / df1['total_amenity_count']
## df1['security_ratio'] = df1['security_amenity_count'] / df1['total_amenity_count']
## df1['maintenance_ratio'] = df1['maintenance_or_cleaning_amenity_count'] / df1['total_amenity_count']
## df1['social_ratio'] = df1['social_amenity_count'] / df1['total_amenity_count']
## df1['expendable_ratio'] = df1['expendable_amenity_count'] / df1['total_amenity_count']
## df1['service_staff_ratio'] = df1['service_staff_amenity_count'] / df1['total_amenity_count']
## df1['unclassify_ratio'] = df1['unclassify_amenity_count'] / df1['total_amenity_count']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29813 entries, 0 to 29812
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   building_type                          29813 non-null  object
#  1   building_nature                        29813 non-null  object
#  2   num_bath_rooms                         29813 non-null  float64
#  3   num_bed_rooms                          29813 non-null  float64
#  4   price                                  29813 non-null  float64
#  5   purpose                                29813 non-null  object
#  6   city                                   29813 non-null  object
#  7   locality                               29813 non-null  object
#  8   relaxation_amenity_count               29813 non-null  int64
#  9   security_amenity_count                 29813 non-null  int64
#  10  maintenance_or_cleaning_amenity_count  29813 non-null  int64
#  11  social_amenity_count                   29813 non-null  int64
#  12  expendable_amenity_count               29813 non-null  int64
#  13  service_staff_amenity_count            29813 non-null  int64
#  14  unclassify_amenity_count               29813 non-null  int64
#  15  division                               29812 non-null  object
#  16  zone                                   29733 non-null  object
# dtypes: float64(3), int64(7), object(7)
# memory usage: 3.9+ MB

# %%
## 'total_amenity_count' , 'relaxation_amenity_count', 'security_amenity_count' ,'maintenance_or_cleaning_amenity_count', 'social_amenity_count', 'expendable_amenity_count','service_staff_amenity_count', 'unclassify_amenity_count

# %%
# Let's also identify the numeric and categorical columns.

numeric_cols = list(df1.select_dtypes(include=np.number).columns)
categorical_cols = list(df1.select_dtypes(include='object').columns)

print('numeric columns: ', numeric_cols)
print('categorical columns: ', categorical_cols)
# Out:
# numeric columns:  ['num_bath_rooms', 'num_bed_rooms', 'price', 'relaxation_amenity_count', 'security_amenity_count', 'maintenance_or_cleaning_amenity_count', 'social_amenity_count', 'expendable_amenity_count', 'service_staff_amenity_count', 'unclassify_amenity_count']
# categorical columns:  ['building_type', 'building_nature', 'purpose', 'city', 'locality', 'division', 'zone']

# %%
#One-Hot encoding categotical variables in the data
df1 = pd.get_dummies(df1)
df1.shape
# Out:
# (29813, 343)

# %%
#################

# %%
x = df1.drop(['price'],axis=1)
y = df1[['price']]
x.shape,y.shape
# Out:
# ((29813, 342), (29813, 1))

# %%
#the natural logarithm transformation to the target variable y using the np.log1p() function. This transformation is commonly used when dealing with skewed data or when trying to normalize the target variable.

y = np.log1p(y)

# %%
from sklearn import model_selection

# Rest of your code using model_selection module

# train-test_split
X_train, X_val, y_train, y_val = model_selection.train_test_split(x,y,test_size=0.20, random_state=42)

# %% [markdown]
# By using Standardscaler as an example, this approach scales the features to a specific range. It's important to fit the scaler on the training data and then apply the same transformation to the validation data. This ensures that both the training and validation sets are scaled consistently.
#
# By applying the normalization or scaling after the train-test split, you ensure that the scaling is based solely on the training data and prevent any data leakage from the validation set. This helps to maintain the integrity of the evaluation process and provides a more accurate assessment of the model's performance.

# %%
# Check for missing values
missing_values = df1.isnull().sum()

# Print variables with missing values
print("Variables with missing values:")
print(missing_values[missing_values > 0])
# Out:
# Variables with missing values:
# Series([], dtype: int64)

# %%
# Apply StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from sklearn.linear_model import Ridge
from yellowbrick.regressor import PredictionError, ResidualsPlot
import lightgbm as lgb

# %% [markdown]
# The output is regression type so accuracy cannot be used as a measure to compare different models like classification models, so all the models are compared using mean absolute error (MAE) and RMSE.
# **The lower the value of mean absolute error the better the model is performing and lower values of RMSE indicate better fit.**

# %%
def regressionmodel(model_s,X_train, X_val, y_train, y_val):
    model_s=model_s.fit(X_train,y_train)#Fitting train data for sales
    y_pred=model_s.predict(X_val)#predicting sales with test data
    print('Model parameter used are:',model_s) #Printing the model to see which parameters are used
    #Printing mean absolute error for predicting sales
    print("MAE of sales is         :", metrics.mean_absolute_error(y_val,y_pred))
    #Printing Root mean squared error for predicting sales
    print("RMSE of sales is        :",np.sqrt(metrics.mean_squared_error(y_val,y_pred)))

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn import linear_model

# Rest of your code using linear_model module
model_s = linear_model.Lasso(alpha=0.1)
regressionmodel(model_s,X_train, X_val, y_train, y_val)
# Out:
# Model parameter used are: Lasso(alpha=0.1)
# MAE of sales is         : 0.5387728586048764
# RMSE of sales is        : 0.6866690622077605

# %% [markdown]
# ## Ridge Regression

# %%
model_s = Ridge(alpha=1.0)
regressionmodel(model_s,X_train, X_val, y_train, y_val)
# Out:
# Model parameter used are: Ridge()
# MAE of sales is         : 0.35159931595881416
# RMSE of sales is        : 0.5104855477909721

# %% [markdown]
# ## Light Gradient Boosting Regression

# %%
model_s = lgb.LGBMRegressor()
regressionmodel(model_s,X_train, X_val, y_train, y_val)
# Out:
# Model parameter used are: LGBMRegressor()
# MAE of sales is         : 0.30481038572091806
# RMSE of sales is        : 0.4447292289975793

# %% [markdown]
# ## Random Forest Regression

# %%
model_s = RandomForestRegressor(n_estimators=100,max_depth=10, random_state=40)
regressionmodel(model_s,X_train, X_val, y_train, y_val)
# Out:
# Model parameter used are: RandomForestRegressor(max_depth=10, random_state=40)
# MAE of sales is         : 0.3343495465633481
# RMSE of sales is        : 0.47616687447584594

# %% [markdown]
# ## eXtreme Gradient Boosting Regression

# %%
model_s = xgb.XGBRegressor()
regressionmodel(model_s,X_train, X_val, y_train, y_val)
# Out:
# Model parameter used are: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# MAE of sales is         : 0.2991906064525452
# RMSE of sales is        : 0.4400458113948689

# %% [markdown]
# ## Decision Tree Regression

# %%
model_s = tree.DecisionTreeRegressor()
regressionmodel(model_s,X_train, X_val, y_train, y_val)
# Out:
# Model parameter used are: DecisionTreeRegressor()
# MAE of sales is         : 0.29535306821591883
# RMSE of sales is        : 0.463928910162184

# %% [markdown]
# ### For better understanding and comparision of all the scores a dataframe is created

# %%
#Giving column Values
Regression_data = {'Regression Model':  ['Lasso','Ridge','Light Gradient Boosting','Random Forest',
                                 'eXtreme gradient boosting','Decision tree'],
        'MAE Value for Sales' :        [0.538,0.351,0.304,0.334,0.299,0.295],
        'RMSE Value for Sales':        [0.686,0.510,0.444,0.476,0.440,0.463], }
#Creating data frame with Column Names
Regression_comparision = pd.DataFrame (Regression_data, columns = ['Regression Model','MAE Value for Sales','RMSE Value for Sales'])

# %%
Regression_comparision #Printing dataframe
# Out:
#             Regression Model  MAE Value for Sales  RMSE Value for Sales
# 0                      Lasso                0.538                 0.686
# 1                      Ridge                0.351                 0.510
# 2    Light Gradient Boosting                0.304                 0.444
# 3              Random Forest                0.334                 0.476
# 4  eXtreme gradient boosting                0.299                 0.440
# 5              Decision tree                0.295                 0.463

# %% [markdown]
# # Best model after tuning hyperparaters

# %%
def regressionmodel(model_s, X_train, X_val, y_train, y_val):
    model_s.fit(X_train, y_train)
    y_pred = model_s.predict(X_val)
    print('Model parameters used:', model_s)
    print("MAE of sales is:", metrics.mean_absolute_error(y_val, y_pred))
    print("RMSE of sales is:", np.sqrt(metrics.mean_squared_error(y_val, y_pred)))

# %% [markdown]
# ## Lasso with hyperparameter tuning

# %%
from sklearn.model_selection import RandomizedSearchCV
# Define the Lasso model
model_s = linear_model.Lasso()

# Define the parameter grid for hyperparameter tuning
param_grid = {'alpha': [0.1, 1.0, 10.0]}

# Create the GridSearchCV object with cross-validation
random_search = RandomizedSearchCV(estimator=model_s, param_distributions=param_grid, n_iter=10, cv=5)

# Perform hyperparameter tuning and get the best model
best_model = random_search.fit(X_train, y_train)

# Use the best model for prediction and evaluation
regressionmodel(best_model, X_train, X_val, y_train, y_val)

# Print the best hyperparameters
print("Best hyperparameters:", best_model.best_params_)
# Out:
# Model parameters used: RandomizedSearchCV(cv=5, estimator=Lasso(),
#                    param_distributions={'alpha': [0.1, 1.0, 10.0]})
# MAE of sales is: 0.5387728586048764
# RMSE of sales is: 0.6866690622077605
# Best hyperparameters: {'alpha': 0.1}

# %% [markdown]
# ## Ridge with hyperparameter tuning

# %%
# Define the Ridge model
model_s = linear_model.Ridge()

# Define the parameter grid for hyperparameter tuning
param_grid = {'alpha': [0.1, 1.0, 10.0]}

# Create the GridSearchCV object with cross-validation
random_search = RandomizedSearchCV(estimator=model_s, param_distributions=param_grid, n_iter=10, cv=5)

# Perform hyperparameter tuning and get the best model
best_model = random_search.fit(X_train, y_train)

# Use the best model for prediction and evaluation
regressionmodel(best_model, X_train, X_val, y_train, y_val)

# Print the best hyperparameters
print("Best hyperparameters:", best_model.best_params_)
# Out:
# Model parameters used: RandomizedSearchCV(cv=5, estimator=Ridge(),
#                    param_distributions={'alpha': [0.1, 1.0, 10.0]})
# MAE of sales is: 0.35167061814977335
# RMSE of sales is: 0.5104447280490049
# Best hyperparameters: {'alpha': 10.0}

# %% [markdown]
# ## Light gradiaent boosting with hyperparameters

# %%
# Define the LightGBM model
model_s = lgb.LGBMRegressor()

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': [3, 5, 7],
    'num_leaves': [31, 63, 127]
}

# Create the RandomizedSearchCV object with cross-validation
random_search = RandomizedSearchCV(estimator=model_s, param_distributions=param_grid, n_iter=10, cv=5)

# Perform hyperparameter tuning and get the best model
best_model = random_search.fit(X_train, y_train)

# Use the best model for prediction and evaluation
regressionmodel(best_model, X_train, X_val, y_train, y_val)

# Print the best hyperparameters
print("Best hyperparameters:", best_model.best_params_)
# Out:
# Model parameters used: RandomizedSearchCV(cv=5, estimator=LGBMRegressor(),
#                    param_distributions={'learning_rate': [0.1, 0.01, 0.001],
#                                         'max_depth': [3, 5, 7],
#                                         'num_leaves': [31, 63, 127]})
# MAE of sales is: 0.30651770645629733
# RMSE of sales is: 0.44819760582105556
# Best hyperparameters: {'num_leaves': 127, 'max_depth': 7, 'learning_rate': 0.1}

# %% [markdown]
# ## Random forest with hyperparamters tuning

# %%
# Define the Random Forest Regressor model
model_s = RandomForestRegressor()

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [10, 20, 50],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

# Create the GridSearchCV object with cross-validation
grid_search = GridSearchCV(estimator=model_s, param_grid=param_grid, cv=5)

# Perform hyperparameter tuning and get the best model
best_model = grid_search.fit(X_train, y_train)

# Use the best model for prediction and evaluation
regressionmodel(best_model, X_train, X_val, y_train, y_val)

# Print the best hyperparameters
print("Best hyperparameters:", best_model.best_params_)
# Out:
# Model parameters used: GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 20, 50]})
# MAE of sales is: 0.2873727054723697
# RMSE of sales is: 0.43474171815794005
# Best hyperparameters: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 50}

# %%
from sklearn.model_selection import RandomizedSearchCV

# Define the Random Forest Regressor model# Define the Random Forest Regressor model
model_s = RandomForestRegressor()

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [10, 20, 50],
    'max_depth': [None],
    'min_samples_split': [2, 5, 10]
}

# Create the RandomizedSearchCV object with cross-validation
random_search = RandomizedSearchCV(estimator=model_s, param_distributions=param_grid, cv=5, n_iter=10)

# Perform hyperparameter tuning and get the best model
best_model = random_search.fit(X_train, y_train)

# Use the best model for prediction and evaluation
regressionmodel(best_model, X_train, X_val, y_train, y_val)

# Print the best hyperparameters
print("Best hyperparameters:", best_model.best_params_)
# Out:
# Model parameters used: RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [None],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [10, 20, 50]})
# MAE of sales is: 0.28689920547184805
# RMSE of sales is: 0.434223576564332
# Best hyperparameters: {'n_estimators': 50, 'min_samples_split': 10, 'max_depth': None}

# %% [markdown]
# # eXtreme Graident Boosting with hyperparameter tuning

# %%
## randomized search takes three less meniutes to run the model
param_grid = {
    'learning_rate': [0.1, 0.01],
    'max_depth': [None],
    'n_estimators': [10, 20, 50],
    'subsample': [0.8, 0.9]
}

# Create the XGBoost model
model_xgb = xgb.XGBRegressor()

# Create the RandomizedSearchCV object with cross-validation
random_search = RandomizedSearchCV(estimator=model_xgb, param_distributions=param_grid, cv=5, n_iter=10)

# Perform hyperparameter tuning and get the best model
best_model = random_search.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_val, y_val)])

# Use the best model for prediction and evaluation
regressionmodel(best_model, X_train, X_val, y_train, y_val)

# Print the best hyperparameters
print("Best hyperparameters:", best_model.best_params_)
# Out:
# [0]	validation_0-rmse:11.26411
# [1]	validation_0-rmse:10.14257
# [2]	validation_0-rmse:9.13354
# [3]	validation_0-rmse:8.22542
# [4]	validation_0-rmse:7.40824
# [5]	validation_0-rmse:6.67312
# [6]	validation_0-rmse:6.01196
# [7]	validation_0-rmse:5.41727
# [8]	validation_0-rmse:4.88254
# [9]	validation_0-rmse:4.40152
# [10]	validation_0-rmse:3.96983
# [11]	validation_0-rmse:3.58129
# [12]	validation_0-rmse:3.23257
# [13]	validation_0-rmse:2.91944
# [14]	validation_0-rmse:2.63804
# [15]	validation_0-rmse:2.38584
# [16]	validation_0-rmse:2.15958
# [17]	validation_0-rmse:1.95678
# [18]	validation_0-rmse:1.77514
# [19]	validation_0-rmse:1.61367
# [0]	validation_0-rmse:11.26422
# [1]	validation_0-rmse:10.14237
# [2]	validation_0-rmse:9.13327
# [3]	validation_0-rmse:8.22506
# [4]	validation_0-rmse:7.40784
# [5]	validation_0-rmse:6.67291
# [6]	validation_0-rmse:6.01186
# [7]	validation_0-rmse:5.41717
# [8]	validation_0-rmse:4.88242
# [9]	validation_0-rmse:4.40160
# [10]	validation_0-rmse:3.96973
# [11]	validation_0-rmse:3.58133
# [12]	validation_0-rmse:3.23277
# [13]	validation_0-rmse:2.91956
# [14]	validation_0-rmse:2.63776
# [15]	validation_0-rmse:2.38514
# [16]	validation_0-rmse:2.15863
# [17]	validation_0-rmse:1.95588
# [18]	validation_0-rmse:1.77444
# [19]	validation_0-rmse:1.61247
# [0]	validation_0-rmse:11.26410
# [1]	validation_0-rmse:10.14210
# [2]	validation_0-rmse:9.13271
# [3]	validation_0-rmse:8.22480
# [4]	validation_0-rmse:7.40723
# [5]	validation_0-rmse:6.67218
# [6]	validation_0-rmse:6.01151
# [7]	validation_0-rmse:5.41683
# [8]	validation_0-rmse:4.88216
# [9]	validation_0-rmse:4.40102
# [10]	validation_0-rmse:3.96850
# [11]	validation_0-rmse:3.58003
# [12]	validation_0-rmse:3.23152
# [13]	validation_0-rmse:2.91838
# [14]	validation_0-rmse:2.63731
# [15]	validation_0-rmse:2.38492
# [16]	validation_0-rmse:2.15885
# [17]	validation_0-rmse:1.95597
# [18]	validation_0-rmse:1.77486
# [19]	validation_0-rmse:1.61303
# [0]	validation_0-rmse:11.26401
# [1]	validation_0-rmse:10.14196
# [2]	validation_0-rmse:9.13251
# [3]	validation_0-rmse:8.22481
# [4]	validation_0-rmse:7.40764
# [5]	validation_0-rmse:6.67238
# [6]	validation_0-rmse:6.01165
# [7]	validation_0-rmse:5.41676
# [8]	validation_0-rmse:4.88198
# [9]	validation_0-rmse:4.40099
# [10]	validation_0-rmse:3.96871
# [11]	validation_0-rmse:3.58027
# [12]	validation_0-rmse:3.23155
# [13]	validation_0-rmse:2.91837
# [14]	validation_0-rmse:2.63665
# [15]	validation_0-rmse:2.38467
# [16]	validation_0-rmse:2.15836
# [17]	validation_0-rmse:1.95567
# [18]	validation_0-rmse:1.77448
# [19]	validation_0-rmse:1.61257
# [0]	validation_0-rmse:11.26422
# [1]	validation_0-rmse:10.14226
# [2]	validation_0-rmse:9.13301
# [3]	validation_0-rmse:8.22483
# [4]	validation_0-rmse:7.40780
# [5]	validation_0-rmse:6.67257
# [6]	validation_0-rmse:6.01148
# [7]	validation_0-rmse:5.41695
# [8]	validation_0-rmse:4.88270
# [9]	validation_0-rmse:4.40184
# [10]	validation_0-rmse:3.96950
# [11]	validation_0-rmse:3.58115
# [12]	validation_0-rmse:3.23277
# [13]	validation_0-rmse:2.91948
# [14]	validation_0-rmse:2.63863
# [15]	validation_0-rmse:2.38627
# [16]	validation_0-rmse:2.15970
# [17]	validation_0-rmse:1.95765
# [18]	validation_0-rmse:1.77613
# [19]	validation_0-rmse:1.61364
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26296
# [2]	validation_0-rmse:12.14078
# [3]	validation_0-rmse:12.01980
# [4]	validation_0-rmse:11.90004
# [5]	validation_0-rmse:11.78150
# [6]	validation_0-rmse:11.66409
# [7]	validation_0-rmse:11.54792
# [8]	validation_0-rmse:11.43289
# [9]	validation_0-rmse:11.31899
# [0]	validation_0-rmse:12.38637
# [1]	validation_0-rmse:12.26293
# [2]	validation_0-rmse:12.14072
# [3]	validation_0-rmse:12.01974
# [4]	validation_0-rmse:11.89997
# [5]	validation_0-rmse:11.78139
# [6]	validation_0-rmse:11.66401
# [7]	validation_0-rmse:11.54779
# [8]	validation_0-rmse:11.43274
# [9]	validation_0-rmse:11.31882
# [0]	validation_0-rmse:12.38637
# [1]	validation_0-rmse:12.26289
# [2]	validation_0-rmse:12.14066
# [3]	validation_0-rmse:12.01968
# [4]	validation_0-rmse:11.89987
# [5]	validation_0-rmse:11.78128
# [6]	validation_0-rmse:11.66387
# [7]	validation_0-rmse:11.54763
# [8]	validation_0-rmse:11.43258
# [9]	validation_0-rmse:11.31864
# [0]	validation_0-rmse:12.38636
# [1]	validation_0-rmse:12.26288
# [2]	validation_0-rmse:12.14065
# [3]	validation_0-rmse:12.01966
# [4]	validation_0-rmse:11.89988
# [5]	validation_0-rmse:11.78127
# [6]	validation_0-rmse:11.66387
# [7]	validation_0-rmse:11.54763
# [8]	validation_0-rmse:11.43256
# [9]	validation_0-rmse:11.31862
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26293
# [2]	validation_0-rmse:12.14073
# [3]	validation_0-rmse:12.01977
# [4]	validation_0-rmse:11.89997
# [5]	validation_0-rmse:11.78137
# [6]	validation_0-rmse:11.66400
# [7]	validation_0-rmse:11.54779
# [8]	validation_0-rmse:11.43274
# [9]	validation_0-rmse:11.31883
# [0]	validation_0-rmse:11.26423
# [1]	validation_0-rmse:10.14259
# [2]	validation_0-rmse:9.13350
# [3]	validation_0-rmse:8.22501
# [4]	validation_0-rmse:7.40843
# [5]	validation_0-rmse:6.67324
# [6]	validation_0-rmse:6.01213
# [7]	validation_0-rmse:5.41746
# [8]	validation_0-rmse:4.88262
# [9]	validation_0-rmse:4.40192
# [0]	validation_0-rmse:11.26402
# [1]	validation_0-rmse:10.14220
# [2]	validation_0-rmse:9.13284
# [3]	validation_0-rmse:8.22480
# [4]	validation_0-rmse:7.40806
# [5]	validation_0-rmse:6.67284
# [6]	validation_0-rmse:6.01186
# [7]	validation_0-rmse:5.41743
# [8]	validation_0-rmse:4.88248
# [9]	validation_0-rmse:4.40127
# [0]	validation_0-rmse:11.26401
# [1]	validation_0-rmse:10.14189
# [2]	validation_0-rmse:9.13232
# [3]	validation_0-rmse:8.22429
# [4]	validation_0-rmse:7.40702
# [5]	validation_0-rmse:6.67195
# [6]	validation_0-rmse:6.01104
# [7]	validation_0-rmse:5.41641
# [8]	validation_0-rmse:4.88202
# [9]	validation_0-rmse:4.40121
# [0]	validation_0-rmse:11.26391
# [1]	validation_0-rmse:10.14178
# [2]	validation_0-rmse:9.13210
# [3]	validation_0-rmse:8.22409
# [4]	validation_0-rmse:7.40675
# [5]	validation_0-rmse:6.67148
# [6]	validation_0-rmse:6.01063
# [7]	validation_0-rmse:5.41605
# [8]	validation_0-rmse:4.88119
# [9]	validation_0-rmse:4.40015
# [0]	validation_0-rmse:11.26425
# [1]	validation_0-rmse:10.14206
# [2]	validation_0-rmse:9.13274
# [3]	validation_0-rmse:8.22472
# [4]	validation_0-rmse:7.40776
# [5]	validation_0-rmse:6.67243
# [6]	validation_0-rmse:6.01128
# [7]	validation_0-rmse:5.41651
# [8]	validation_0-rmse:4.88211
# [9]	validation_0-rmse:4.40134
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26296
# [2]	validation_0-rmse:12.14078
# [3]	validation_0-rmse:12.01980
# [4]	validation_0-rmse:11.90004
# [5]	validation_0-rmse:11.78150
# [6]	validation_0-rmse:11.66409
# [7]	validation_0-rmse:11.54792
# [8]	validation_0-rmse:11.43289
# [9]	validation_0-rmse:11.31899
# [10]	validation_0-rmse:11.20626
# [11]	validation_0-rmse:11.09465
# [12]	validation_0-rmse:10.98414
# [13]	validation_0-rmse:10.87475
# [14]	validation_0-rmse:10.76644
# [15]	validation_0-rmse:10.65924
# [16]	validation_0-rmse:10.55311
# [17]	validation_0-rmse:10.44802
# [18]	validation_0-rmse:10.34398
# [19]	validation_0-rmse:10.24098
# [20]	validation_0-rmse:10.13906
# [21]	validation_0-rmse:10.03813
# [22]	validation_0-rmse:9.93823
# [23]	validation_0-rmse:9.83934
# [24]	validation_0-rmse:9.74141
# [25]	validation_0-rmse:9.64446
# [26]	validation_0-rmse:9.54846
# [27]	validation_0-rmse:9.45346
# [28]	validation_0-rmse:9.35941
# [29]	validation_0-rmse:9.26630
# [30]	validation_0-rmse:9.17411
# [31]	validation_0-rmse:9.08283
# [32]	validation_0-rmse:8.99253
# [33]	validation_0-rmse:8.90309
# [34]	validation_0-rmse:8.81459
# [35]	validation_0-rmse:8.72696
# [36]	validation_0-rmse:8.64023
# [37]	validation_0-rmse:8.55436
# [38]	validation_0-rmse:8.46933
# [39]	validation_0-rmse:8.38513
# [40]	validation_0-rmse:8.30181
# [41]	validation_0-rmse:8.21931
# [42]	validation_0-rmse:8.13767
# [43]	validation_0-rmse:8.05681
# [44]	validation_0-rmse:7.97681
# [45]	validation_0-rmse:7.89754
# [46]	validation_0-rmse:7.81912
# [47]	validation_0-rmse:7.74145
# [48]	validation_0-rmse:7.66457
# [49]	validation_0-rmse:7.58844
# [0]	validation_0-rmse:12.38637
# [1]	validation_0-rmse:12.26293
# [2]	validation_0-rmse:12.14072
# [3]	validation_0-rmse:12.01974
# [4]	validation_0-rmse:11.89997
# [5]	validation_0-rmse:11.78139
# [6]	validation_0-rmse:11.66401
# [7]	validation_0-rmse:11.54779
# [8]	validation_0-rmse:11.43274
# [9]	validation_0-rmse:11.31882
# [10]	validation_0-rmse:11.20607
# [11]	validation_0-rmse:11.09444
# [12]	validation_0-rmse:10.98394
# [13]	validation_0-rmse:10.87453
# [14]	validation_0-rmse:10.76620
# [15]	validation_0-rmse:10.65898
# [16]	validation_0-rmse:10.55283
# [17]	validation_0-rmse:10.44776
# [18]	validation_0-rmse:10.34374
# [19]	validation_0-rmse:10.24073
# [20]	validation_0-rmse:10.13879
# [21]	validation_0-rmse:10.03784
# [22]	validation_0-rmse:9.93793
# [23]	validation_0-rmse:9.83901
# [24]	validation_0-rmse:9.74108
# [25]	validation_0-rmse:9.64412
# [26]	validation_0-rmse:9.54813
# [27]	validation_0-rmse:9.45312
# [28]	validation_0-rmse:9.35906
# [29]	validation_0-rmse:9.26595
# [30]	validation_0-rmse:9.17373
# [31]	validation_0-rmse:9.08245
# [32]	validation_0-rmse:8.99212
# [33]	validation_0-rmse:8.90268
# [34]	validation_0-rmse:8.81416
# [35]	validation_0-rmse:8.72653
# [36]	validation_0-rmse:8.63977
# [37]	validation_0-rmse:8.55385
# [38]	validation_0-rmse:8.46884
# [39]	validation_0-rmse:8.38462
# [40]	validation_0-rmse:8.30130
# [41]	validation_0-rmse:8.21883
# [42]	validation_0-rmse:8.13718
# [43]	validation_0-rmse:8.05632
# [44]	validation_0-rmse:7.97629
# [45]	validation_0-rmse:7.89704
# [46]	validation_0-rmse:7.81860
# [47]	validation_0-rmse:7.74095
# [48]	validation_0-rmse:7.66406
# [49]	validation_0-rmse:7.58795
# [0]	validation_0-rmse:12.38637
# [1]	validation_0-rmse:12.26289
# [2]	validation_0-rmse:12.14066
# [3]	validation_0-rmse:12.01968
# [4]	validation_0-rmse:11.89987
# [5]	validation_0-rmse:11.78128
# [6]	validation_0-rmse:11.66387
# [7]	validation_0-rmse:11.54763
# [8]	validation_0-rmse:11.43258
# [9]	validation_0-rmse:11.31864
# [10]	validation_0-rmse:11.20586
# [11]	validation_0-rmse:11.09424
# [12]	validation_0-rmse:10.98372
# [13]	validation_0-rmse:10.87432
# [14]	validation_0-rmse:10.76600
# [15]	validation_0-rmse:10.65876
# [16]	validation_0-rmse:10.55260
# [17]	validation_0-rmse:10.44753
# [18]	validation_0-rmse:10.34350
# [19]	validation_0-rmse:10.24051
# [20]	validation_0-rmse:10.13856
# [21]	validation_0-rmse:10.03762
# [22]	validation_0-rmse:9.93768
# [23]	validation_0-rmse:9.83875
# [24]	validation_0-rmse:9.74084
# [25]	validation_0-rmse:9.64389
# [26]	validation_0-rmse:9.54788
# [27]	validation_0-rmse:9.45287
# [28]	validation_0-rmse:9.35882
# [29]	validation_0-rmse:9.26568
# [30]	validation_0-rmse:9.17346
# [31]	validation_0-rmse:9.08217
# [32]	validation_0-rmse:8.99185
# [33]	validation_0-rmse:8.90239
# [34]	validation_0-rmse:8.81383
# [35]	validation_0-rmse:8.72618
# [36]	validation_0-rmse:8.63937
# [37]	validation_0-rmse:8.55346
# [38]	validation_0-rmse:8.46842
# [39]	validation_0-rmse:8.38419
# [40]	validation_0-rmse:8.30082
# [41]	validation_0-rmse:8.21832
# [42]	validation_0-rmse:8.13663
# [43]	validation_0-rmse:8.05579
# [44]	validation_0-rmse:7.97573
# [45]	validation_0-rmse:7.89652
# [46]	validation_0-rmse:7.81806
# [47]	validation_0-rmse:7.74041
# [48]	validation_0-rmse:7.66351
# [49]	validation_0-rmse:7.58739
# [0]	validation_0-rmse:12.38636
# [1]	validation_0-rmse:12.26288
# [2]	validation_0-rmse:12.14065
# [3]	validation_0-rmse:12.01966
# [4]	validation_0-rmse:11.89988
# [5]	validation_0-rmse:11.78127
# [6]	validation_0-rmse:11.66387
# [7]	validation_0-rmse:11.54763
# [8]	validation_0-rmse:11.43256
# [9]	validation_0-rmse:11.31862
# [10]	validation_0-rmse:11.20584
# [11]	validation_0-rmse:11.09422
# [12]	validation_0-rmse:10.98369
# [13]	validation_0-rmse:10.87429
# [14]	validation_0-rmse:10.76597
# [15]	validation_0-rmse:10.65874
# [16]	validation_0-rmse:10.55255
# [17]	validation_0-rmse:10.44748
# [18]	validation_0-rmse:10.34346
# [19]	validation_0-rmse:10.24046
# [20]	validation_0-rmse:10.13848
# [21]	validation_0-rmse:10.03754
# [22]	validation_0-rmse:9.93761
# [23]	validation_0-rmse:9.83866
# [24]	validation_0-rmse:9.74073
# [25]	validation_0-rmse:9.64379
# [26]	validation_0-rmse:9.54779
# [27]	validation_0-rmse:9.45279
# [28]	validation_0-rmse:9.35873
# [29]	validation_0-rmse:9.26559
# [30]	validation_0-rmse:9.17335
# [31]	validation_0-rmse:9.08206
# [32]	validation_0-rmse:8.99173
# [33]	validation_0-rmse:8.90232
# [34]	validation_0-rmse:8.81379
# [35]	validation_0-rmse:8.72613
# [36]	validation_0-rmse:8.63935
# [37]	validation_0-rmse:8.55346
# [38]	validation_0-rmse:8.46844
# [39]	validation_0-rmse:8.38425
# [40]	validation_0-rmse:8.30088
# [41]	validation_0-rmse:8.21837
# [42]	validation_0-rmse:8.13666
# [43]	validation_0-rmse:8.05577
# [44]	validation_0-rmse:7.97570
# [45]	validation_0-rmse:7.89647
# [46]	validation_0-rmse:7.81802
# [47]	validation_0-rmse:7.74037
# [48]	validation_0-rmse:7.66352
# [49]	validation_0-rmse:7.58742
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26293
# [2]	validation_0-rmse:12.14073
# [3]	validation_0-rmse:12.01977
# [4]	validation_0-rmse:11.89997
# [5]	validation_0-rmse:11.78137
# [6]	validation_0-rmse:11.66400
# [7]	validation_0-rmse:11.54779
# [8]	validation_0-rmse:11.43274
# [9]	validation_0-rmse:11.31883
# [10]	validation_0-rmse:11.20606
# [11]	validation_0-rmse:11.09444
# [12]	validation_0-rmse:10.98391
# [13]	validation_0-rmse:10.87451
# [14]	validation_0-rmse:10.76622
# [15]	validation_0-rmse:10.65898
# [16]	validation_0-rmse:10.55286
# [17]	validation_0-rmse:10.44781
# [18]	validation_0-rmse:10.34381
# [19]	validation_0-rmse:10.24083
# [20]	validation_0-rmse:10.13891
# [21]	validation_0-rmse:10.03798
# [22]	validation_0-rmse:9.93805
# [23]	validation_0-rmse:9.83911
# [24]	validation_0-rmse:9.74121
# [25]	validation_0-rmse:9.64429
# [26]	validation_0-rmse:9.54830
# [27]	validation_0-rmse:9.45330
# [28]	validation_0-rmse:9.35924
# [29]	validation_0-rmse:9.26615
# [30]	validation_0-rmse:9.17394
# [31]	validation_0-rmse:9.08270
# [32]	validation_0-rmse:8.99241
# [33]	validation_0-rmse:8.90300
# [34]	validation_0-rmse:8.81449
# [35]	validation_0-rmse:8.72684
# [36]	validation_0-rmse:8.64007
# [37]	validation_0-rmse:8.55423
# [38]	validation_0-rmse:8.46925
# [39]	validation_0-rmse:8.38503
# [40]	validation_0-rmse:8.30172
# [41]	validation_0-rmse:8.21921
# [42]	validation_0-rmse:8.13752
# [43]	validation_0-rmse:8.05666
# [44]	validation_0-rmse:7.97660
# [45]	validation_0-rmse:7.89739
# [46]	validation_0-rmse:7.81893
# [47]	validation_0-rmse:7.74128
# [48]	validation_0-rmse:7.66438
# [49]	validation_0-rmse:7.58826
# [0]	validation_0-rmse:11.26411
# [1]	validation_0-rmse:10.14257
# [2]	validation_0-rmse:9.13354
# [3]	validation_0-rmse:8.22542
# [4]	validation_0-rmse:7.40824
# [5]	validation_0-rmse:6.67312
# [6]	validation_0-rmse:6.01196
# [7]	validation_0-rmse:5.41727
# [8]	validation_0-rmse:4.88254
# [9]	validation_0-rmse:4.40152
# [0]	validation_0-rmse:11.26422
# [1]	validation_0-rmse:10.14237
# [2]	validation_0-rmse:9.13327
# [3]	validation_0-rmse:8.22506
# [4]	validation_0-rmse:7.40784
# [5]	validation_0-rmse:6.67291
# [6]	validation_0-rmse:6.01186
# [7]	validation_0-rmse:5.41717
# [8]	validation_0-rmse:4.88242
# [9]	validation_0-rmse:4.40160
# [0]	validation_0-rmse:11.26410
# [1]	validation_0-rmse:10.14210
# [2]	validation_0-rmse:9.13271
# [3]	validation_0-rmse:8.22480
# [4]	validation_0-rmse:7.40723
# [5]	validation_0-rmse:6.67218
# [6]	validation_0-rmse:6.01151
# [7]	validation_0-rmse:5.41683
# [8]	validation_0-rmse:4.88216
# [9]	validation_0-rmse:4.40102
# [0]	validation_0-rmse:11.26401
# [1]	validation_0-rmse:10.14196
# [2]	validation_0-rmse:9.13251
# [3]	validation_0-rmse:8.22481
# [4]	validation_0-rmse:7.40764
# [5]	validation_0-rmse:6.67238
# [6]	validation_0-rmse:6.01165
# [7]	validation_0-rmse:5.41676
# [8]	validation_0-rmse:4.88198
# [9]	validation_0-rmse:4.40099
# [0]	validation_0-rmse:11.26422
# [1]	validation_0-rmse:10.14226
# [2]	validation_0-rmse:9.13301
# [3]	validation_0-rmse:8.22483
# [4]	validation_0-rmse:7.40780
# [5]	validation_0-rmse:6.67257
# [6]	validation_0-rmse:6.01148
# [7]	validation_0-rmse:5.41695
# [8]	validation_0-rmse:4.88270
# [9]	validation_0-rmse:4.40184
# [0]	validation_0-rmse:12.38638
# [1]	validation_0-rmse:12.26294
# [2]	validation_0-rmse:12.14077
# [3]	validation_0-rmse:12.01980
# [4]	validation_0-rmse:11.90004
# [5]	validation_0-rmse:11.78149
# [6]	validation_0-rmse:11.66410
# [7]	validation_0-rmse:11.54792
# [8]	validation_0-rmse:11.43285
# [9]	validation_0-rmse:11.31896
# [10]	validation_0-rmse:11.20622
# [11]	validation_0-rmse:11.09462
# [12]	validation_0-rmse:10.98415
# [13]	validation_0-rmse:10.87477
# [14]	validation_0-rmse:10.76641
# [15]	validation_0-rmse:10.65922
# [16]	validation_0-rmse:10.55311
# [17]	validation_0-rmse:10.44803
# [18]	validation_0-rmse:10.34397
# [19]	validation_0-rmse:10.24098
# [20]	validation_0-rmse:10.13906
# [21]	validation_0-rmse:10.03812
# [22]	validation_0-rmse:9.93821
# [23]	validation_0-rmse:9.83930
# [24]	validation_0-rmse:9.74138
# [25]	validation_0-rmse:9.64445
# [26]	validation_0-rmse:9.54848
# [27]	validation_0-rmse:9.45350
# [28]	validation_0-rmse:9.35944
# [29]	validation_0-rmse:9.26636
# [30]	validation_0-rmse:9.17417
# [31]	validation_0-rmse:9.08289
# [32]	validation_0-rmse:8.99257
# [33]	validation_0-rmse:8.90314
# [34]	validation_0-rmse:8.81461
# [35]	validation_0-rmse:8.72699
# [36]	validation_0-rmse:8.64028
# [37]	validation_0-rmse:8.55438
# [38]	validation_0-rmse:8.46939
# [39]	validation_0-rmse:8.38520
# [40]	validation_0-rmse:8.30191
# [41]	validation_0-rmse:8.21942
# [42]	validation_0-rmse:8.13774
# [43]	validation_0-rmse:8.05692
# [44]	validation_0-rmse:7.97691
# [45]	validation_0-rmse:7.89771
# [46]	validation_0-rmse:7.81935
# [47]	validation_0-rmse:7.74170
# [48]	validation_0-rmse:7.66480
# [49]	validation_0-rmse:7.58870
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26296
# [2]	validation_0-rmse:12.14078
# [3]	validation_0-rmse:12.01980
# [4]	validation_0-rmse:11.90004
# [5]	validation_0-rmse:11.78148
# [6]	validation_0-rmse:11.66409
# [7]	validation_0-rmse:11.54788
# [8]	validation_0-rmse:11.43281
# [9]	validation_0-rmse:11.31893
# [10]	validation_0-rmse:11.20619
# [11]	validation_0-rmse:11.09453
# [12]	validation_0-rmse:10.98406
# [13]	validation_0-rmse:10.87465
# [14]	validation_0-rmse:10.76631
# [15]	validation_0-rmse:10.65908
# [16]	validation_0-rmse:10.55296
# [17]	validation_0-rmse:10.44786
# [18]	validation_0-rmse:10.34381
# [19]	validation_0-rmse:10.24083
# [20]	validation_0-rmse:10.13888
# [21]	validation_0-rmse:10.03792
# [22]	validation_0-rmse:9.93799
# [23]	validation_0-rmse:9.83908
# [24]	validation_0-rmse:9.74116
# [25]	validation_0-rmse:9.64422
# [26]	validation_0-rmse:9.54824
# [27]	validation_0-rmse:9.45322
# [28]	validation_0-rmse:9.35915
# [29]	validation_0-rmse:9.26607
# [30]	validation_0-rmse:9.17388
# [31]	validation_0-rmse:9.08260
# [32]	validation_0-rmse:8.99225
# [33]	validation_0-rmse:8.90280
# [34]	validation_0-rmse:8.81427
# [35]	validation_0-rmse:8.72660
# [36]	validation_0-rmse:8.63986
# [37]	validation_0-rmse:8.55396
# [38]	validation_0-rmse:8.46894
# [39]	validation_0-rmse:8.38472
# [40]	validation_0-rmse:8.30139
# [41]	validation_0-rmse:8.21893
# [42]	validation_0-rmse:8.13729
# [43]	validation_0-rmse:8.05645
# [44]	validation_0-rmse:7.97643
# [45]	validation_0-rmse:7.89718
# [46]	validation_0-rmse:7.81877
# [47]	validation_0-rmse:7.74112
# [48]	validation_0-rmse:7.66424
# [49]	validation_0-rmse:7.58812
# [0]	validation_0-rmse:12.38638
# [1]	validation_0-rmse:12.26291
# [2]	validation_0-rmse:12.14070
# [3]	validation_0-rmse:12.01974
# [4]	validation_0-rmse:11.89993
# [5]	validation_0-rmse:11.78137
# [6]	validation_0-rmse:11.66397
# [7]	validation_0-rmse:11.54775
# [8]	validation_0-rmse:11.43268
# [9]	validation_0-rmse:11.31875
# [10]	validation_0-rmse:11.20598
# [11]	validation_0-rmse:11.09434
# [12]	validation_0-rmse:10.98382
# [13]	validation_0-rmse:10.87444
# [14]	validation_0-rmse:10.76609
# [15]	validation_0-rmse:10.65889
# [16]	validation_0-rmse:10.55275
# [17]	validation_0-rmse:10.44763
# [18]	validation_0-rmse:10.34359
# [19]	validation_0-rmse:10.24061
# [20]	validation_0-rmse:10.13869
# [21]	validation_0-rmse:10.03773
# [22]	validation_0-rmse:9.93782
# [23]	validation_0-rmse:9.83889
# [24]	validation_0-rmse:9.74095
# [25]	validation_0-rmse:9.64401
# [26]	validation_0-rmse:9.54803
# [27]	validation_0-rmse:9.45302
# [28]	validation_0-rmse:9.35897
# [29]	validation_0-rmse:9.26588
# [30]	validation_0-rmse:9.17367
# [31]	validation_0-rmse:9.08237
# [32]	validation_0-rmse:8.99203
# [33]	validation_0-rmse:8.90257
# [34]	validation_0-rmse:8.81401
# [35]	validation_0-rmse:8.72634
# [36]	validation_0-rmse:8.63955
# [37]	validation_0-rmse:8.55366
# [38]	validation_0-rmse:8.46864
# [39]	validation_0-rmse:8.38440
# [40]	validation_0-rmse:8.30108
# [41]	validation_0-rmse:8.21858
# [42]	validation_0-rmse:8.13688
# [43]	validation_0-rmse:8.05607
# [44]	validation_0-rmse:7.97604
# [45]	validation_0-rmse:7.89682
# [46]	validation_0-rmse:7.81837
# [47]	validation_0-rmse:7.74074
# [48]	validation_0-rmse:7.66385
# [49]	validation_0-rmse:7.58774
# [0]	validation_0-rmse:12.38637
# [1]	validation_0-rmse:12.26290
# [2]	validation_0-rmse:12.14069
# [3]	validation_0-rmse:12.01971
# [4]	validation_0-rmse:11.89993
# [5]	validation_0-rmse:11.78133
# [6]	validation_0-rmse:11.66394
# [7]	validation_0-rmse:11.54771
# [8]	validation_0-rmse:11.43266
# [9]	validation_0-rmse:11.31874
# [10]	validation_0-rmse:11.20594
# [11]	validation_0-rmse:11.09432
# [12]	validation_0-rmse:10.98381
# [13]	validation_0-rmse:10.87442
# [14]	validation_0-rmse:10.76608
# [15]	validation_0-rmse:10.65887
# [16]	validation_0-rmse:10.55273
# [17]	validation_0-rmse:10.44762
# [18]	validation_0-rmse:10.34359
# [19]	validation_0-rmse:10.24056
# [20]	validation_0-rmse:10.13862
# [21]	validation_0-rmse:10.03768
# [22]	validation_0-rmse:9.93774
# [23]	validation_0-rmse:9.83883
# [24]	validation_0-rmse:9.74087
# [25]	validation_0-rmse:9.64389
# [26]	validation_0-rmse:9.54792
# [27]	validation_0-rmse:9.45290
# [28]	validation_0-rmse:9.35884
# [29]	validation_0-rmse:9.26573
# [30]	validation_0-rmse:9.17350
# [31]	validation_0-rmse:9.08221
# [32]	validation_0-rmse:8.99188
# [33]	validation_0-rmse:8.90243
# [34]	validation_0-rmse:8.81390
# [35]	validation_0-rmse:8.72623
# [36]	validation_0-rmse:8.63948
# [37]	validation_0-rmse:8.55361
# [38]	validation_0-rmse:8.46858
# [39]	validation_0-rmse:8.38442
# [40]	validation_0-rmse:8.30107
# [41]	validation_0-rmse:8.21859
# [42]	validation_0-rmse:8.13692
# [43]	validation_0-rmse:8.05607
# [44]	validation_0-rmse:7.97599
# [45]	validation_0-rmse:7.89679
# [46]	validation_0-rmse:7.81834
# [47]	validation_0-rmse:7.74072
# [48]	validation_0-rmse:7.66385
# [49]	validation_0-rmse:7.58774
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26295
# [2]	validation_0-rmse:12.14074
# [3]	validation_0-rmse:12.01978
# [4]	validation_0-rmse:11.89998
# [5]	validation_0-rmse:11.78140
# [6]	validation_0-rmse:11.66403
# [7]	validation_0-rmse:11.54784
# [8]	validation_0-rmse:11.43282
# [9]	validation_0-rmse:11.31892
# [10]	validation_0-rmse:11.20614
# [11]	validation_0-rmse:11.09452
# [12]	validation_0-rmse:10.98403
# [13]	validation_0-rmse:10.87466
# [14]	validation_0-rmse:10.76635
# [15]	validation_0-rmse:10.65914
# [16]	validation_0-rmse:10.55304
# [17]	validation_0-rmse:10.44796
# [18]	validation_0-rmse:10.34393
# [19]	validation_0-rmse:10.24094
# [20]	validation_0-rmse:10.13902
# [21]	validation_0-rmse:10.03806
# [22]	validation_0-rmse:9.93811
# [23]	validation_0-rmse:9.83921
# [24]	validation_0-rmse:9.74134
# [25]	validation_0-rmse:9.64443
# [26]	validation_0-rmse:9.54844
# [27]	validation_0-rmse:9.45344
# [28]	validation_0-rmse:9.35941
# [29]	validation_0-rmse:9.26632
# [30]	validation_0-rmse:9.17411
# [31]	validation_0-rmse:9.08286
# [32]	validation_0-rmse:8.99257
# [33]	validation_0-rmse:8.90314
# [34]	validation_0-rmse:8.81460
# [35]	validation_0-rmse:8.72693
# [36]	validation_0-rmse:8.64017
# [37]	validation_0-rmse:8.55431
# [38]	validation_0-rmse:8.46930
# [39]	validation_0-rmse:8.38512
# [40]	validation_0-rmse:8.30179
# [41]	validation_0-rmse:8.21929
# [42]	validation_0-rmse:8.13764
# [43]	validation_0-rmse:8.05675
# [44]	validation_0-rmse:7.97672
# [45]	validation_0-rmse:7.89753
# [46]	validation_0-rmse:7.81904
# [47]	validation_0-rmse:7.74143
# [48]	validation_0-rmse:7.66456
# [49]	validation_0-rmse:7.58845
# [0]	validation_0-rmse:12.38638
# [1]	validation_0-rmse:12.26294
# [2]	validation_0-rmse:12.14077
# [3]	validation_0-rmse:12.01980
# [4]	validation_0-rmse:11.90004
# [5]	validation_0-rmse:11.78149
# [6]	validation_0-rmse:11.66410
# [7]	validation_0-rmse:11.54792
# [8]	validation_0-rmse:11.43285
# [9]	validation_0-rmse:11.31896
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26296
# [2]	validation_0-rmse:12.14078
# [3]	validation_0-rmse:12.01980
# [4]	validation_0-rmse:11.90004
# [5]	validation_0-rmse:11.78148
# [6]	validation_0-rmse:11.66409
# [7]	validation_0-rmse:11.54788
# [8]	validation_0-rmse:11.43281
# [9]	validation_0-rmse:11.31893
# [0]	validation_0-rmse:12.38638
# [1]	validation_0-rmse:12.26291
# [2]	validation_0-rmse:12.14070
# [3]	validation_0-rmse:12.01974
# [4]	validation_0-rmse:11.89993
# [5]	validation_0-rmse:11.78137
# [6]	validation_0-rmse:11.66397
# [7]	validation_0-rmse:11.54775
# [8]	validation_0-rmse:11.43268
# [9]	validation_0-rmse:11.31875
# [0]	validation_0-rmse:12.38637
# [1]	validation_0-rmse:12.26290
# [2]	validation_0-rmse:12.14069
# [3]	validation_0-rmse:12.01971
# [4]	validation_0-rmse:11.89993
# [5]	validation_0-rmse:11.78133
# [6]	validation_0-rmse:11.66394
# [7]	validation_0-rmse:11.54771
# [8]	validation_0-rmse:11.43266
# [9]	validation_0-rmse:11.31874
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26295
# [2]	validation_0-rmse:12.14074
# [3]	validation_0-rmse:12.01978
# [4]	validation_0-rmse:11.89998
# [5]	validation_0-rmse:11.78140
# [6]	validation_0-rmse:11.66403
# [7]	validation_0-rmse:11.54784
# [8]	validation_0-rmse:11.43282
# [9]	validation_0-rmse:11.31892
# [0]	validation_0-rmse:12.38638
# [1]	validation_0-rmse:12.26294
# [2]	validation_0-rmse:12.14077
# [3]	validation_0-rmse:12.01980
# [4]	validation_0-rmse:11.90004
# [5]	validation_0-rmse:11.78149
# [6]	validation_0-rmse:11.66410
# [7]	validation_0-rmse:11.54792
# [8]	validation_0-rmse:11.43285
# [9]	validation_0-rmse:11.31896
# [10]	validation_0-rmse:11.20622
# [11]	validation_0-rmse:11.09462
# [12]	validation_0-rmse:10.98415
# [13]	validation_0-rmse:10.87477
# [14]	validation_0-rmse:10.76641
# [15]	validation_0-rmse:10.65922
# [16]	validation_0-rmse:10.55311
# [17]	validation_0-rmse:10.44803
# [18]	validation_0-rmse:10.34397
# [19]	validation_0-rmse:10.24098
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26296
# [2]	validation_0-rmse:12.14078
# [3]	validation_0-rmse:12.01980
# [4]	validation_0-rmse:11.90004
# [5]	validation_0-rmse:11.78148
# [6]	validation_0-rmse:11.66409
# [7]	validation_0-rmse:11.54788
# [8]	validation_0-rmse:11.43281
# [9]	validation_0-rmse:11.31893
# [10]	validation_0-rmse:11.20619
# [11]	validation_0-rmse:11.09453
# [12]	validation_0-rmse:10.98406
# [13]	validation_0-rmse:10.87465
# [14]	validation_0-rmse:10.76631
# [15]	validation_0-rmse:10.65908
# [16]	validation_0-rmse:10.55296
# [17]	validation_0-rmse:10.44786
# [18]	validation_0-rmse:10.34381
# [19]	validation_0-rmse:10.24083
# [0]	validation_0-rmse:12.38638
# [1]	validation_0-rmse:12.26291
# [2]	validation_0-rmse:12.14070
# [3]	validation_0-rmse:12.01974
# [4]	validation_0-rmse:11.89993
# [5]	validation_0-rmse:11.78137
# [6]	validation_0-rmse:11.66397
# [7]	validation_0-rmse:11.54775
# [8]	validation_0-rmse:11.43268
# [9]	validation_0-rmse:11.31875
# [10]	validation_0-rmse:11.20598
# [11]	validation_0-rmse:11.09434
# [12]	validation_0-rmse:10.98382
# [13]	validation_0-rmse:10.87444
# [14]	validation_0-rmse:10.76609
# [15]	validation_0-rmse:10.65889
# [16]	validation_0-rmse:10.55275
# [17]	validation_0-rmse:10.44763
# [18]	validation_0-rmse:10.34359
# [19]	validation_0-rmse:10.24061
# [0]	validation_0-rmse:12.38637
# [1]	validation_0-rmse:12.26290
# [2]	validation_0-rmse:12.14069
# [3]	validation_0-rmse:12.01971
# [4]	validation_0-rmse:11.89993
# [5]	validation_0-rmse:11.78133
# [6]	validation_0-rmse:11.66394
# [7]	validation_0-rmse:11.54771
# [8]	validation_0-rmse:11.43266
# [9]	validation_0-rmse:11.31874
# [10]	validation_0-rmse:11.20594
# [11]	validation_0-rmse:11.09432
# [12]	validation_0-rmse:10.98381
# [13]	validation_0-rmse:10.87442
# [14]	validation_0-rmse:10.76608
# [15]	validation_0-rmse:10.65887
# [16]	validation_0-rmse:10.55273
# [17]	validation_0-rmse:10.44762
# [18]	validation_0-rmse:10.34359
# [19]	validation_0-rmse:10.24056
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26295
# [2]	validation_0-rmse:12.14074
# [3]	validation_0-rmse:12.01978
# [4]	validation_0-rmse:11.89998
# [5]	validation_0-rmse:11.78140
# [6]	validation_0-rmse:11.66403
# [7]	validation_0-rmse:11.54784
# [8]	validation_0-rmse:11.43282
# [9]	validation_0-rmse:11.31892
# [10]	validation_0-rmse:11.20614
# [11]	validation_0-rmse:11.09452
# [12]	validation_0-rmse:10.98403
# [13]	validation_0-rmse:10.87466
# [14]	validation_0-rmse:10.76635
# [15]	validation_0-rmse:10.65914
# [16]	validation_0-rmse:10.55304
# [17]	validation_0-rmse:10.44796
# [18]	validation_0-rmse:10.34393
# [19]	validation_0-rmse:10.24094
# [0]	validation_0-rmse:11.26411
# [1]	validation_0-rmse:10.14257
# [2]	validation_0-rmse:9.13354
# [3]	validation_0-rmse:8.22542
# [4]	validation_0-rmse:7.40824
# [5]	validation_0-rmse:6.67312
# [6]	validation_0-rmse:6.01196
# [7]	validation_0-rmse:5.41727
# [8]	validation_0-rmse:4.88254
# [9]	validation_0-rmse:4.40152
# [10]	validation_0-rmse:3.96983
# [11]	validation_0-rmse:3.58129
# [12]	validation_0-rmse:3.23257
# [13]	validation_0-rmse:2.91944
# [14]	validation_0-rmse:2.63804
# [15]	validation_0-rmse:2.38584
# [16]	validation_0-rmse:2.15958
# [17]	validation_0-rmse:1.95678
# [18]	validation_0-rmse:1.77514
# [19]	validation_0-rmse:1.61367
# [20]	validation_0-rmse:1.46904
# [21]	validation_0-rmse:1.34020
# [22]	validation_0-rmse:1.22596
# [23]	validation_0-rmse:1.12432
# [24]	validation_0-rmse:1.03509
# [25]	validation_0-rmse:0.95633
# [26]	validation_0-rmse:0.88723
# [27]	validation_0-rmse:0.82637
# [28]	validation_0-rmse:0.77366
# [29]	validation_0-rmse:0.72825
# [30]	validation_0-rmse:0.68890
# [31]	validation_0-rmse:0.65487
# [32]	validation_0-rmse:0.62603
# [33]	validation_0-rmse:0.60134
# [34]	validation_0-rmse:0.58075
# [35]	validation_0-rmse:0.56302
# [36]	validation_0-rmse:0.54817
# [37]	validation_0-rmse:0.53547
# [38]	validation_0-rmse:0.52476
# [39]	validation_0-rmse:0.51595
# [40]	validation_0-rmse:0.50879
# [41]	validation_0-rmse:0.50270
# [42]	validation_0-rmse:0.49758
# [43]	validation_0-rmse:0.49314
# [44]	validation_0-rmse:0.48914
# [45]	validation_0-rmse:0.48580
# [46]	validation_0-rmse:0.48280
# [47]	validation_0-rmse:0.48056
# [48]	validation_0-rmse:0.47836
# [49]	validation_0-rmse:0.47677
# [0]	validation_0-rmse:11.26422
# [1]	validation_0-rmse:10.14237
# [2]	validation_0-rmse:9.13327
# [3]	validation_0-rmse:8.22506
# [4]	validation_0-rmse:7.40784
# [5]	validation_0-rmse:6.67291
# [6]	validation_0-rmse:6.01186
# [7]	validation_0-rmse:5.41717
# [8]	validation_0-rmse:4.88242
# [9]	validation_0-rmse:4.40160
# [10]	validation_0-rmse:3.96973
# [11]	validation_0-rmse:3.58133
# [12]	validation_0-rmse:3.23277
# [13]	validation_0-rmse:2.91956
# [14]	validation_0-rmse:2.63776
# [15]	validation_0-rmse:2.38514
# [16]	validation_0-rmse:2.15863
# [17]	validation_0-rmse:1.95588
# [18]	validation_0-rmse:1.77444
# [19]	validation_0-rmse:1.61247
# [20]	validation_0-rmse:1.46823
# [21]	validation_0-rmse:1.33925
# [22]	validation_0-rmse:1.22552
# [23]	validation_0-rmse:1.12431
# [24]	validation_0-rmse:1.03500
# [25]	validation_0-rmse:0.95614
# [26]	validation_0-rmse:0.88721
# [27]	validation_0-rmse:0.82647
# [28]	validation_0-rmse:0.77365
# [29]	validation_0-rmse:0.72838
# [30]	validation_0-rmse:0.68874
# [31]	validation_0-rmse:0.65469
# [32]	validation_0-rmse:0.62579
# [33]	validation_0-rmse:0.60076
# [34]	validation_0-rmse:0.58022
# [35]	validation_0-rmse:0.56271
# [36]	validation_0-rmse:0.54770
# [37]	validation_0-rmse:0.53490
# [38]	validation_0-rmse:0.52439
# [39]	validation_0-rmse:0.51558
# [40]	validation_0-rmse:0.50838
# [41]	validation_0-rmse:0.50212
# [42]	validation_0-rmse:0.49672
# [43]	validation_0-rmse:0.49191
# [44]	validation_0-rmse:0.48806
# [45]	validation_0-rmse:0.48493
# [46]	validation_0-rmse:0.48186
# [47]	validation_0-rmse:0.47931
# [48]	validation_0-rmse:0.47689
# [49]	validation_0-rmse:0.47530
# [0]	validation_0-rmse:11.26410
# [1]	validation_0-rmse:10.14210
# [2]	validation_0-rmse:9.13271
# [3]	validation_0-rmse:8.22480
# [4]	validation_0-rmse:7.40723
# [5]	validation_0-rmse:6.67218
# [6]	validation_0-rmse:6.01151
# [7]	validation_0-rmse:5.41683
# [8]	validation_0-rmse:4.88216
# [9]	validation_0-rmse:4.40102
# [10]	validation_0-rmse:3.96850
# [11]	validation_0-rmse:3.58003
# [12]	validation_0-rmse:3.23152
# [13]	validation_0-rmse:2.91838
# [14]	validation_0-rmse:2.63731
# [15]	validation_0-rmse:2.38492
# [16]	validation_0-rmse:2.15885
# [17]	validation_0-rmse:1.95597
# [18]	validation_0-rmse:1.77486
# [19]	validation_0-rmse:1.61303
# [20]	validation_0-rmse:1.46905
# [21]	validation_0-rmse:1.33993
# [22]	validation_0-rmse:1.22590
# [23]	validation_0-rmse:1.12482
# [24]	validation_0-rmse:1.03519
# [25]	validation_0-rmse:0.95641
# [26]	validation_0-rmse:0.88748
# [27]	validation_0-rmse:0.82691
# [28]	validation_0-rmse:0.77434
# [29]	validation_0-rmse:0.72882
# [30]	validation_0-rmse:0.68929
# [31]	validation_0-rmse:0.65478
# [32]	validation_0-rmse:0.62593
# [33]	validation_0-rmse:0.60123
# [34]	validation_0-rmse:0.58044
# [35]	validation_0-rmse:0.56281
# [36]	validation_0-rmse:0.54796
# [37]	validation_0-rmse:0.53521
# [38]	validation_0-rmse:0.52452
# [39]	validation_0-rmse:0.51559
# [40]	validation_0-rmse:0.50817
# [41]	validation_0-rmse:0.50173
# [42]	validation_0-rmse:0.49659
# [43]	validation_0-rmse:0.49212
# [44]	validation_0-rmse:0.48794
# [45]	validation_0-rmse:0.48440
# [46]	validation_0-rmse:0.48152
# [47]	validation_0-rmse:0.47902
# [48]	validation_0-rmse:0.47685
# [49]	validation_0-rmse:0.47497
# [0]	validation_0-rmse:11.26401
# [1]	validation_0-rmse:10.14196
# [2]	validation_0-rmse:9.13251
# [3]	validation_0-rmse:8.22481
# [4]	validation_0-rmse:7.40764
# [5]	validation_0-rmse:6.67238
# [6]	validation_0-rmse:6.01165
# [7]	validation_0-rmse:5.41676
# [8]	validation_0-rmse:4.88198
# [9]	validation_0-rmse:4.40099
# [10]	validation_0-rmse:3.96871
# [11]	validation_0-rmse:3.58027
# [12]	validation_0-rmse:3.23155
# [13]	validation_0-rmse:2.91837
# [14]	validation_0-rmse:2.63665
# [15]	validation_0-rmse:2.38467
# [16]	validation_0-rmse:2.15836
# [17]	validation_0-rmse:1.95567
# [18]	validation_0-rmse:1.77448
# [19]	validation_0-rmse:1.61257
# [20]	validation_0-rmse:1.46870
# [21]	validation_0-rmse:1.33954
# [22]	validation_0-rmse:1.22542
# [23]	validation_0-rmse:1.12443
# [24]	validation_0-rmse:1.03473
# [25]	validation_0-rmse:0.95588
# [26]	validation_0-rmse:0.88678
# [27]	validation_0-rmse:0.82594
# [28]	validation_0-rmse:0.77338
# [29]	validation_0-rmse:0.72791
# [30]	validation_0-rmse:0.68811
# [31]	validation_0-rmse:0.65365
# [32]	validation_0-rmse:0.62519
# [33]	validation_0-rmse:0.60044
# [34]	validation_0-rmse:0.57926
# [35]	validation_0-rmse:0.56151
# [36]	validation_0-rmse:0.54626
# [37]	validation_0-rmse:0.53345
# [38]	validation_0-rmse:0.52280
# [39]	validation_0-rmse:0.51373
# [40]	validation_0-rmse:0.50626
# [41]	validation_0-rmse:0.49968
# [42]	validation_0-rmse:0.49444
# [43]	validation_0-rmse:0.48985
# [44]	validation_0-rmse:0.48570
# [45]	validation_0-rmse:0.48258
# [46]	validation_0-rmse:0.47985
# [47]	validation_0-rmse:0.47735
# [48]	validation_0-rmse:0.47512
# [49]	validation_0-rmse:0.47355
# [0]	validation_0-rmse:11.26422
# [1]	validation_0-rmse:10.14226
# [2]	validation_0-rmse:9.13301
# [3]	validation_0-rmse:8.22483
# [4]	validation_0-rmse:7.40780
# [5]	validation_0-rmse:6.67257
# [6]	validation_0-rmse:6.01148
# [7]	validation_0-rmse:5.41695
# [8]	validation_0-rmse:4.88270
# [9]	validation_0-rmse:4.40184
# [10]	validation_0-rmse:3.96950
# [11]	validation_0-rmse:3.58115
# [12]	validation_0-rmse:3.23277
# [13]	validation_0-rmse:2.91948
# [14]	validation_0-rmse:2.63863
# [15]	validation_0-rmse:2.38627
# [16]	validation_0-rmse:2.15970
# [17]	validation_0-rmse:1.95765
# [18]	validation_0-rmse:1.77613
# [19]	validation_0-rmse:1.61364
# [20]	validation_0-rmse:1.46908
# [21]	validation_0-rmse:1.33984
# [22]	validation_0-rmse:1.22543
# [23]	validation_0-rmse:1.12448
# [24]	validation_0-rmse:1.03491
# [25]	validation_0-rmse:0.95612
# [26]	validation_0-rmse:0.88717
# [27]	validation_0-rmse:0.82698
# [28]	validation_0-rmse:0.77450
# [29]	validation_0-rmse:0.72876
# [30]	validation_0-rmse:0.68913
# [31]	validation_0-rmse:0.65508
# [32]	validation_0-rmse:0.62621
# [33]	validation_0-rmse:0.60145
# [34]	validation_0-rmse:0.58027
# [35]	validation_0-rmse:0.56219
# [36]	validation_0-rmse:0.54672
# [37]	validation_0-rmse:0.53416
# [38]	validation_0-rmse:0.52367
# [39]	validation_0-rmse:0.51467
# [40]	validation_0-rmse:0.50721
# [41]	validation_0-rmse:0.50052
# [42]	validation_0-rmse:0.49482
# [43]	validation_0-rmse:0.49003
# [44]	validation_0-rmse:0.48608
# [45]	validation_0-rmse:0.48306
# [46]	validation_0-rmse:0.48047
# [47]	validation_0-rmse:0.47780
# [48]	validation_0-rmse:0.47540
# [49]	validation_0-rmse:0.47350
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26296
# [2]	validation_0-rmse:12.14078
# [3]	validation_0-rmse:12.01980
# [4]	validation_0-rmse:11.90004
# [5]	validation_0-rmse:11.78150
# [6]	validation_0-rmse:11.66409
# [7]	validation_0-rmse:11.54792
# [8]	validation_0-rmse:11.43289
# [9]	validation_0-rmse:11.31899
# [10]	validation_0-rmse:11.20626
# [11]	validation_0-rmse:11.09465
# [12]	validation_0-rmse:10.98414
# [13]	validation_0-rmse:10.87475
# [14]	validation_0-rmse:10.76644
# [15]	validation_0-rmse:10.65924
# [16]	validation_0-rmse:10.55311
# [17]	validation_0-rmse:10.44802
# [18]	validation_0-rmse:10.34398
# [19]	validation_0-rmse:10.24098
# [0]	validation_0-rmse:12.38637
# [1]	validation_0-rmse:12.26293
# [2]	validation_0-rmse:12.14072
# [3]	validation_0-rmse:12.01974
# [4]	validation_0-rmse:11.89997
# [5]	validation_0-rmse:11.78139
# [6]	validation_0-rmse:11.66401
# [7]	validation_0-rmse:11.54779
# [8]	validation_0-rmse:11.43274
# [9]	validation_0-rmse:11.31882
# [10]	validation_0-rmse:11.20607
# [11]	validation_0-rmse:11.09444
# [12]	validation_0-rmse:10.98394
# [13]	validation_0-rmse:10.87453
# [14]	validation_0-rmse:10.76620
# [15]	validation_0-rmse:10.65898
# [16]	validation_0-rmse:10.55283
# [17]	validation_0-rmse:10.44776
# [18]	validation_0-rmse:10.34374
# [19]	validation_0-rmse:10.24073
# [0]	validation_0-rmse:12.38637
# [1]	validation_0-rmse:12.26289
# [2]	validation_0-rmse:12.14066
# [3]	validation_0-rmse:12.01968
# [4]	validation_0-rmse:11.89987
# [5]	validation_0-rmse:11.78128
# [6]	validation_0-rmse:11.66387
# [7]	validation_0-rmse:11.54763
# [8]	validation_0-rmse:11.43258
# [9]	validation_0-rmse:11.31864
# [10]	validation_0-rmse:11.20586
# [11]	validation_0-rmse:11.09424
# [12]	validation_0-rmse:10.98372
# [13]	validation_0-rmse:10.87432
# [14]	validation_0-rmse:10.76600
# [15]	validation_0-rmse:10.65876
# [16]	validation_0-rmse:10.55260
# [17]	validation_0-rmse:10.44753
# [18]	validation_0-rmse:10.34350
# [19]	validation_0-rmse:10.24051
# [0]	validation_0-rmse:12.38636
# [1]	validation_0-rmse:12.26288
# [2]	validation_0-rmse:12.14065
# [3]	validation_0-rmse:12.01966
# [4]	validation_0-rmse:11.89988
# [5]	validation_0-rmse:11.78127
# [6]	validation_0-rmse:11.66387
# [7]	validation_0-rmse:11.54763
# [8]	validation_0-rmse:11.43256
# [9]	validation_0-rmse:11.31862
# [10]	validation_0-rmse:11.20584
# [11]	validation_0-rmse:11.09422
# [12]	validation_0-rmse:10.98369
# [13]	validation_0-rmse:10.87429
# [14]	validation_0-rmse:10.76597
# [15]	validation_0-rmse:10.65874
# [16]	validation_0-rmse:10.55255
# [17]	validation_0-rmse:10.44748
# [18]	validation_0-rmse:10.34346
# [19]	validation_0-rmse:10.24046
# [0]	validation_0-rmse:12.38639
# [1]	validation_0-rmse:12.26293
# [2]	validation_0-rmse:12.14073
# [3]	validation_0-rmse:12.01977
# [4]	validation_0-rmse:11.89997
# [5]	validation_0-rmse:11.78137
# [6]	validation_0-rmse:11.66400
# [7]	validation_0-rmse:11.54779
# [8]	validation_0-rmse:11.43274
# [9]	validation_0-rmse:11.31883
# [10]	validation_0-rmse:11.20606
# [11]	validation_0-rmse:11.09444
# [12]	validation_0-rmse:10.98391
# [13]	validation_0-rmse:10.87451
# [14]	validation_0-rmse:10.76622
# [15]	validation_0-rmse:10.65898
# [16]	validation_0-rmse:10.55286
# [17]	validation_0-rmse:10.44781
# [18]	validation_0-rmse:10.34381
# [19]	validation_0-rmse:10.24083
# [0]	validation_0-rmse:11.26399
# [1]	validation_0-rmse:10.14208
# [2]	validation_0-rmse:9.13257
# [3]	validation_0-rmse:8.22377
# [4]	validation_0-rmse:7.40688
# [5]	validation_0-rmse:6.67159
# [6]	validation_0-rmse:6.01002
# [7]	validation_0-rmse:5.41543
# [8]	validation_0-rmse:4.88031
# [9]	validation_0-rmse:4.39988
# [10]	validation_0-rmse:3.96784
# [11]	validation_0-rmse:3.57925
# [12]	validation_0-rmse:3.23006
# [13]	validation_0-rmse:2.91696
# [14]	validation_0-rmse:2.63581
# [15]	validation_0-rmse:2.38372
# [16]	validation_0-rmse:2.15709
# [17]	validation_0-rmse:1.95427
# [18]	validation_0-rmse:1.77329
# [19]	validation_0-rmse:1.61168
# [20]	validation_0-rmse:1.46724
# [21]	validation_0-rmse:1.33892
# [22]	validation_0-rmse:1.22489
# [23]	validation_0-rmse:1.12340
# [24]	validation_0-rmse:1.03375
# [25]	validation_0-rmse:0.95504
# [26]	validation_0-rmse:0.88603
# [27]	validation_0-rmse:0.82559
# [28]	validation_0-rmse:0.77294
# [29]	validation_0-rmse:0.72725
# [30]	validation_0-rmse:0.68774
# [31]	validation_0-rmse:0.65372
# [32]	validation_0-rmse:0.62454
# [33]	validation_0-rmse:0.59963
# [34]	validation_0-rmse:0.57887
# [35]	validation_0-rmse:0.56113
# [36]	validation_0-rmse:0.54621
# [37]	validation_0-rmse:0.53341
# [38]	validation_0-rmse:0.52287
# [39]	validation_0-rmse:0.51400
# [40]	validation_0-rmse:0.50653
# [41]	validation_0-rmse:0.49969
# [42]	validation_0-rmse:0.49403
# [43]	validation_0-rmse:0.48947
# [44]	validation_0-rmse:0.48587
# [45]	validation_0-rmse:0.48256
# [46]	validation_0-rmse:0.47988
# [47]	validation_0-rmse:0.47739
# [48]	validation_0-rmse:0.47541
# [49]	validation_0-rmse:0.47349
# Model parameters used: RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, gpu_id=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                                           max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=None,
#                                           max_leaves=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           n_estimators=100, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           predictor=None, random_state=None, ...),
#                    param_distributions={'learning_rate': [0.1, 0.01],
#                                         'max_depth': [None],
#                                         'n_estimators': [10, 20, 50],
#                                         'subsample': [0.8, 0.9]})
# MAE of sales is: 0.3308324832364874
# RMSE of sales is: 0.4734914723159034
# Best hyperparameters: {'subsample': 0.8, 'n_estimators': 50, 'max_depth': None, 'learning_rate': 0.1}

# %%
#Giving column Values
Regression_data = {'Regression Model with HP':  ['Lasso','Ridge','Light Gradient Boosting','Random Forest',
                                 'eXtreme gradient boosting','Decision tree'],
        'MAE Value for Sales' :        [0.538,0.351,0.306,0.286,0.331,0.295],
        'RMSE Value for Sales':        [0.686,0.510,0.448,0.434,0.473,0.463], }
#Creating data frame with Column Names
Regression_comparision = pd.DataFrame (Regression_data, columns = ['Regression Model with HP','MAE Value for Sales','RMSE Value for Sales'])

# %%
Regression_comparision #Printing dataframe
# Out:
#     Regression Model with HP  MAE Value for Sales  RMSE Value for Sales
# 0                      Lasso                0.538                 0.686
# 1                      Ridge                0.351                 0.510
# 2    Light Gradient Boosting                0.304                 0.444
# 3              Random Forest                0.334                 0.476
# 4  eXtreme gradient boosting                0.299                 0.440
# 5              Decision tree                0.295                 0.463
