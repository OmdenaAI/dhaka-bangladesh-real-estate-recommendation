# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("output/naveenkumar_sharif.csv")

# %%
df
# Out:
#                             address  \
# 0        Motijheel,Dhaka,Bangladesh
# 1      Bashundhara,Dhaka,Bangladesh
# 2                     Gulshan Dhaka
# 3    Gulshan Dhaka,Dhaka,Bangladesh
# 4          Niketon,Dhaka,Bangladesh
# ..                              ...
# 285        Tongi,Gazipur,Bangladesh
# 286                         Gazipur
# 287                    Banani Dhaka
# 288                   Gulshan Dhaka
# 289                    Banani Dhaka
#
#                                              amenities  bathrooms  bedrooms  \
# 0    Gas Connection,Cable Connection,Parking : 2,Ge...        NaN       NaN
# 1    Gas Connection,Cable Connection,Parking : 1,Ge...        4.0       3.0
# 2    Gas Connection,Cable Connection,Parking : 1,Ge...        NaN       3.0
# 3    Gas Connection,Cable Connection,Parking : 2,Ge...        5.0       4.0
# 4    Gas Connection,Cable Connection,Parking : 1,Ge...        4.0       4.0
# ...

# %%
df["building_type"]="" 
df["building_type"][df["description"].str.contains("apartment|Apartment")|df["title"].str.contains("apartment|Apartment")]="Apartment"
# Out:
# C:\Users\Ragave Manokaran\AppData\Local\Temp\ipykernel_5280\3190669930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["building_type"][df["description"].str.contains("apartment|Apartment")|df["title"].str.contains("apartment|Apartment")]="Apartment"

# %%
df["building_type"]
# Out:
# 0
# 1      Apartment
# 2      Apartment
# 3      Apartment
# 4      Apartment
#          ...
# 285
# 286
# 287    Apartment
# 288
# 289
# Name: building_type, Length: 290, dtype: object

# %%
df["building_type"][df["description"].str.contains("factory|Factory|Industrial Shed|industrial shed")|df["title"].str.contains("factory|Factory|Industrial Shed|industrial shed")]="Factory"
df["building_type"][df["description"].str.contains("office|Office|Commercial space|commercial space|Commercial Space|Commercial Property|commercial property|Commercial Proeprty")|df["title"].str.contains("office|Office|Commercial space|commercial space|Commercial Space")]="Office"
df["building_type"][df["description"].str.contains("warehouse|Warehouse")|df["title"].str.contains("warehouse|Warehouse")]="Warehouse"
df["building_type"][df["description"].str.contains("independent house|Independent House|Independent house")|df["title"].str.contains("independent house|Independent House|Independent house")]="Duplex"
df["building_type"][df["description"].str.contains("showroom|Showroom")|df["title"].str.contains("showroom|Showroom")]="Shop"
df["building_type"][df["description"].str.contains("Industrial building|Palace")]="Building"
# Out:
# C:\Users\Ragave Manokaran\AppData\Local\Temp\ipykernel_5280\853018119.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["building_type"][df["description"].str.contains("factory|Factory|Industrial Shed|industrial shed")|df["title"].str.contains("factory|Factory|Industrial Shed|industrial shed")]="Factory"
# C:\Users\Ragave Manokaran\AppData\Local\Temp\ipykernel_5280\853018119.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df["amenities"].str.split(",")
# Out:
# 0      [Gas Connection, Cable Connection, Parking : 2...
# 1      [Gas Connection, Cable Connection, Parking : 1...
# 2      [Gas Connection, Cable Connection, Parking : 1...
# 3      [Gas Connection, Cable Connection, Parking : 2...
# 4      [Gas Connection, Cable Connection, Parking : 1...
#                              ...
# 285                                        [Parking : 2]
# 286                      [Cable Connection, Parking : 2]
# 287    [Gas Connection, Cable Connection, Parking : 1...
# 288    [Cable Connection, Parking : 2, Generator Avai...
# 289    [Cable Connection, Parking : 1, Generator Avai...
# Name: amenities, Length: 290, dtype: object

# %%
unique_amenities=[]
for i in df["amenities"]:
    if i!="" and type(i)==str:
        j=i.split(",")
        for values in j:
            if (values.strip() not in unique_amenities) and (values.strip() !=""):
                unique_amenities.append(values.strip())
unique_amenities
# Out:
# ['Gas Connection',
#  'Cable Connection',
#  'Parking : 2',
#  'Generator Available',
#  'Parking : 1',
#  'Geyser Available',
#  'Intercom Communication',
#  'Guard Room',
#  'Driver Room',
#  'CCTV',
#  'Dual Sink',
#  'Auto Generator',
#  'Badminton Playground',
#  'Fire Exit',
#  'Fire Extinguisher',
#  'Community Hall Room',
#  'Security Guard',
#  'Child Play Ground',
#  'Roof Top',
#  'Close to Educational Facilities',
#  'Near Groceries Shops',
#  'Swimming Pool',
#  'Parking : 5',
#  'Parking : 4',
#  'Parking : 3',
#  'Parking : 7',
#  'Parking : 8',
#  'Parking : 9',
#  'Parking : 6',
#  'Parking : 10']

# %%
df["cctv-security-amenity"]=np.NaN
df["cctv-security-amenity"][df["amenities"].str.contains("CCTV")==True]="Yes"

df["parking-spaces-amenity"]=np.NaN
df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 1")==True]=1
df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 2")==True]=2
df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 3")==True]=3
df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 4")==True]=4
df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 5")==True]=5
df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 6")==True]=6
df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 7")==True]=7
df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 8")==True]=8
df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 9")==True]=9
df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 10")==True]=10


df["electricity-backup-amenity"]=np.NaN
df["electricity-backup-amenity"][df["amenities"].str.contains("Generator Available")==True]="Yes"

df["balcony-or-terrace-amenity"]=np.NaN
df["balcony-or-terrace-amenity"][df["amenities"].str.contains("Roof Top")==True]="Yes"

df["maintenance-staff-amenity"]=np.NaN
df["maintenance-staff-amenity"][df["amenities"].str.contains("Security Guard")==True]="Yes"

df["swimming-pool-amenity"]=np.NaN
df["swimming-pool-amenity"][df["amenities"].str.contains("Swimming Pool")==True]="Yes"

df["furnished-amenity"]="No"
# Out:
# C:\Users\Ragave Manokaran\AppData\Local\Temp\ipykernel_5280\1393992892.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cctv-security-amenity"][df["amenities"].str.contains("CCTV")==True]="Yes"
# C:\Users\Ragave Manokaran\AppData\Local\Temp\ipykernel_5280\1393992892.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["parking-spaces-amenity"][df["amenities"].str.contains("Parking : 1")==True]=1
# C:\Users\Ragave Manokaran\AppData\Local\Temp\ipykernel_5280\1393992892.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df["furnished-amenity"][df["description"].str.contains("furnished|Furnished")==True|df["title"].str.contains("furnished|Furnished")]="Yes"
# Out:
# C:\Users\Ragave Manokaran\AppData\Local\Temp\ipykernel_5280\2523456122.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["furnished-amenity"][df["description"].str.contains("furnished|Furnished")==True|df["title"].str.contains("furnished|Furnished")]="Yes"

# %%
df.head()
# Out:
#                           address  \
# 0      Motijheel,Dhaka,Bangladesh
# 1    Bashundhara,Dhaka,Bangladesh
# 2                   Gulshan Dhaka
# 3  Gulshan Dhaka,Dhaka,Bangladesh
# 4        Niketon,Dhaka,Bangladesh
#
#                                            amenities  bathrooms  bedrooms  \
# 0  Gas Connection,Cable Connection,Parking : 2,Ge...        NaN       NaN
# 1  Gas Connection,Cable Connection,Parking : 1,Ge...        4.0       3.0
# 2  Gas Connection,Cable Connection,Parking : 1,Ge...        NaN       3.0
# 3  Gas Connection,Cable Connection,Parking : 2,Ge...        5.0       4.0
# 4  Gas Connection,Cable Connection,Parking : 1,Ge...        4.0       4.0
#
#                                          description  garage       price  \
# 0  It is very attractive commercial office buildi...       2  BDT 500000
# 1        furnished apartment for rent in bashundhara       1   BDT 90000
# 2                 luxury furnished apartment gulshan       1  BDT 130000
# ...

# %%
df["price"]=df["price"].str.strip()
df["price"]
# Out:
# 0           BDT 500000
# 1            BDT 90000
# 2           BDT 130000
# 3           BDT 300000
# 4           BDT 100000
#             ...
# 285             BDT 22
# 286             BDT 22
# 287          BDT 70000
# 288            BDT 180
# 289    BDT 110 per sqf
# Name: price, Length: 290, dtype: object

# %%
df["price"][df["price"].str.contains("per")==True]="770000"
# Out:
# C:\Users\Ragave Manokaran\AppData\Local\Temp\ipykernel_5280\1596788155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price"][df["price"].str.contains("per")==True]="770000"

# %%
df["price"]=df["price"].replace("[^0-9]","",regex=True)
df["price"][df["price"].str.contains("Per")]
# Out:
# Series([], Name: price, dtype: object)

# %%
df["price"]=df["price"].astype(float)

# %%
df["price"]
# Out:
# 0      500000.0
# 1       90000.0
# 2      130000.0
# 3      300000.0
# 4      100000.0
#          ...
# 285        22.0
# 286        22.0
# 287     70000.0
# 288       180.0
# 289    770000.0
# Name: price, Length: 290, dtype: float64

# %%
df.head()
# Out:
#                           address  \
# 0      Motijheel,Dhaka,Bangladesh
# 1    Bashundhara,Dhaka,Bangladesh
# 2                   Gulshan Dhaka
# 3  Gulshan Dhaka,Dhaka,Bangladesh
# 4        Niketon,Dhaka,Bangladesh
#
#                                            amenities  bathrooms  bedrooms  \
# 0  Gas Connection,Cable Connection,Parking : 2,Ge...        NaN       NaN
# 1  Gas Connection,Cable Connection,Parking : 1,Ge...        4.0       3.0
# 2  Gas Connection,Cable Connection,Parking : 1,Ge...        NaN       3.0
# 3  Gas Connection,Cable Connection,Parking : 2,Ge...        5.0       4.0
# 4  Gas Connection,Cable Connection,Parking : 1,Ge...        4.0       4.0
#
#                                          description  garage     price  \
# 0  It is very attractive commercial office buildi...       2  500000.0
# 1        furnished apartment for rent in bashundhara       1   90000.0
# 2                 luxury furnished apartment gulshan       1  130000.0
# ...

# %%
df["bathrooms"].fillna(0)
df["bedrooms"].fillna(0)
# Out:
# 0      0.0
# 1      3.0
# 2      3.0
# 3      4.0
# 4      4.0
#       ...
# 285    0.0
# 286    0.0
# 287    1.0
# 288    0.0
# 289    0.0
# Name: bedrooms, Length: 290, dtype: float64

# %%
df.drop(columns=["amenities"],inplace=True)
df.head()
# Out:
#                           address  bathrooms  bedrooms  \
# 0      Motijheel,Dhaka,Bangladesh        NaN       NaN
# 1    Bashundhara,Dhaka,Bangladesh        4.0       3.0
# 2                   Gulshan Dhaka        NaN       3.0
# 3  Gulshan Dhaka,Dhaka,Bangladesh        5.0       4.0
# 4        Niketon,Dhaka,Bangladesh        4.0       4.0
#
#                                          description  garage     price  \
# 0  It is very attractive commercial office buildi...       2  500000.0
# 1        furnished apartment for rent in bashundhara       1   90000.0
# 2                 luxury furnished apartment gulshan       1  130000.0
# 3                  Fully furnished apartment gulshan       2  300000.0
# 4                          service apartment Niketon       1  100000.0
#
#   property_type                                       property_url sq_ft  \
# 0          Rent  https://sharif.com.bd/dhaka/10361/office-space...  9000
# ...

# %%
#df["address"] = [ele[0] for ele in df["address"].str.split(",")]

# %%
#df["city"]="Dhaka"

# %%
df.head()
# Out:
#                           address  bathrooms  bedrooms  \
# 0      Motijheel,Dhaka,Bangladesh        NaN       NaN
# 1    Bashundhara,Dhaka,Bangladesh        4.0       3.0
# 2                   Gulshan Dhaka        NaN       3.0
# 3  Gulshan Dhaka,Dhaka,Bangladesh        5.0       4.0
# 4        Niketon,Dhaka,Bangladesh        4.0       4.0
#
#                                          description  garage     price  \
# 0  It is very attractive commercial office buildi...       2  500000.0
# 1        furnished apartment for rent in bashundhara       1   90000.0
# 2                 luxury furnished apartment gulshan       1  130000.0
# 3                  Fully furnished apartment gulshan       2  300000.0
# 4                          service apartment Niketon       1  100000.0
#
#   property_type                                       property_url sq_ft  \
# 0          Rent  https://sharif.com.bd/dhaka/10361/office-space...  9000
# ...

# %%
df.rename(columns = {'description':'property_overview'}, inplace = True)
df.rename(columns = {'title':'property_description'}, inplace = True)

# %%
df.drop(columns=["year_built","garage"],inplace=True)

# %%
df["building_nature"]="Commercial"
df["building_nature"][df["building_type"].str.contains("Apartment|Duplex")]="Residential"
# Out:
# C:\Users\Ragave Manokaran\AppData\Local\Temp\ipykernel_5280\168959162.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["building_nature"][df["building_type"].str.contains("Apartment|Duplex")]="Residential"

# %%
df.rename(columns = {'bedrooms':'num_bed_rooms'}, inplace = True)
df.rename(columns = {'bathrooms':'num_bath_rooms'}, inplace = True)
df.rename(columns = {'property_type':'purpose'}, inplace = True)
df.rename(columns = {'sq_ft':'area'}, inplace = True)

# %%
df.head()
# Out:
#                           address  num_bath_rooms  num_bed_rooms  \
# 0      Motijheel,Dhaka,Bangladesh             NaN            NaN
# 1    Bashundhara,Dhaka,Bangladesh             4.0            3.0
# 2                   Gulshan Dhaka             NaN            3.0
# 3  Gulshan Dhaka,Dhaka,Bangladesh             5.0            4.0
# 4        Niketon,Dhaka,Bangladesh             4.0            4.0
#
#                                    property_overview     price purpose  \
# 0  It is very attractive commercial office buildi...  500000.0    Rent
# 1        furnished apartment for rent in bashundhara   90000.0    Rent
# 2                 luxury furnished apartment gulshan  130000.0    Rent
# 3                  Fully furnished apartment gulshan  300000.0    Rent
# 4                          service apartment Niketon  100000.0    Rent
#
#                                         property_url  area  \
# 0  https://sharif.com.bd/dhaka/10361/office-space...  9000
# ...

# %%
df["num_bath_rooms"].fillna(0,inplace=True)
df["num_bed_rooms"].fillna(0,inplace=True)
df.head()
# Out:
#                           address  num_bath_rooms  num_bed_rooms  \
# 0      Motijheel,Dhaka,Bangladesh             0.0            0.0
# 1    Bashundhara,Dhaka,Bangladesh             4.0            3.0
# 2                   Gulshan Dhaka             0.0            3.0
# 3  Gulshan Dhaka,Dhaka,Bangladesh             5.0            4.0
# 4        Niketon,Dhaka,Bangladesh             4.0            4.0
#
#                                    property_overview     price purpose  \
# 0  It is very attractive commercial office buildi...  500000.0    Rent
# 1        furnished apartment for rent in bashundhara   90000.0    Rent
# 2                 luxury furnished apartment gulshan  130000.0    Rent
# 3                  Fully furnished apartment gulshan  300000.0    Rent
# 4                          service apartment Niketon  100000.0    Rent
#
#                                         property_url  area  \
# 0  https://sharif.com.bd/dhaka/10361/office-space...  9000
# ...

# %%
df["city"] = np.NaN
df["locality"] = np.NaN

# %%
def get_detailed_address(address):
    address = address.title()
    address_dict = {"City": "", "Area": "", "Address": ""}
    splitted_address = address.split(',')

    for i in reversed(splitted_address):
        if get_city_name(i.strip()):
            address_dict["City"] = i.strip()
            splitted_address.remove(i)
        elif get_area_name(i.strip()):
            address_dict["Area"] = i.strip()
            splitted_address.remove(i)

    address_dict["Address"] = ','.join(splitted_address)

    return address_dict


def get_city_name(name):
    cities = ['Dhaka', 'Chattogram', 'Narayanganj City', 'Gazipur', 'Sylhet']

    try:
        cities.index(name)
        return True

    except:
        return False


def get_area_name(name):

    areas = ['10 No. North Kattali Ward', '11 No. South Kattali Ward', '15 No. Bagmoniram Ward',
             '16 No. Chawk Bazaar Ward', '22 No. Enayet Bazaar Ward', '29 No. West Madarbari Ward',
             '30 No. East Madarbari Ward', '31 No. Alkoron Ward', '32 No. Andarkilla Ward',
             '33 No. Firingee Bazaar Ward', '36 Goshail Danga Ward', '4 No Chandgaon Ward',
             '7 No. West Sholoshohor Ward', '9 No. North Pahartali Ward', 'Adabor', 'Aftab Nagar', 'Agargaon',
             'Ambarkhana', 'Badda', 'Bakalia', 'Banani', 'Banani Dohs', 'Banasree', 'Banglamotors', 'Bangshal',
             'Baridhara', 'Baridhara Dohs', 'Bashabo', 'Bashundhara R-A', 'Bayazid', 'Cantonment', 'Chandra',
             'Dakshin Khan', 'Demra', 'Dhanmondi', 'Double Mooring', 'Dumni', 'East Nasirabad', 'Eskaton', 'Fatulla',
             'Firojshah Colony', 'Gazipur Sadar Upazila', 'Gulistan', 'Gulshan', 'Halishahar', 'Hathazari', 'Hatirpool',
             'Hazaribag', 'Ibrahimpur', 'Jalalabad Housing Society', 'Jamal Khan', 'Jatra Bari', 'Joar Sahara',
             'Kachukhet', 'Kafrul', 'Kakrail', 'Kalabagan', 'Kalachandpur', 'Kamrangirchar', 'Kathalbagan',
             'Kazir Dewri', 'Keraniganj', 'Khilgaon', 'Khilkhet', 'Khulshi', 'Kotwali', 'Kuril', 'Lal Khan Bazaar',
             'Lalbagh', 'Lalmatia', 'Maghbazar', 'Malibagh', 'Maniknagar', 'Mirpur', 'Mohakhali', 'Mohakhali Dohs',
             'Mohammadpur', 'Motijheel', 'Mugdapara', 'Muradpur', 'Nadda', 'Narayanganj', 'New Market', 'Niketan',
             'Nikunja', 'North Shahjahanpur', 'Panchlaish', 'Paribagh', 'Patenga', 'Purbachal', 'Railway Colony',
             'Rampura', 'Riaj Uddin Bazar', 'Sagorika Bscic Industrial Area', 'Savar', 'Shahbagh', 'Shahjahanpur',
             'Shantinagar', 'Shegunbagicha', 'Shiddheswari', 'Shiddhirganj', 'Sholokbahar', 'Shyamoli', 'Shyampur',
             'Sreepur', 'Sutrapur', 'Taltola', 'Tejgaon', 'Turag', 'Uttar Khan', 'Uttar Lalkhan', 'Uttara', 'Zafrabad',
             'Zindabazar']
    try:
        areas.index(name)
        return True

    except:
        return False

# %%
for index, row in df.iterrows(): # loop through each sample
    
    # The code may take time, log in the console to keep track of things
    if index==0 or index%1000==0:
        print(f"Currently processing sample {index}...")
        
    # retrieve the location
    location = df.loc[index, "address"]
    
    # split the location to dictionary with Area, City, Address as keys
    location_dict = get_detailed_address(location)
    
    city = location_dict.get("City", np.NaN)
    locality = location_dict.get("Area", np.NaN)
    address = location_dict.get("Address", np.NaN)
    

    # updating the relevant columns of the sample in the dataframe
    df.loc[index, "city"] = city
    df.loc[index, "locality"] = locality
    df.loc[index, "address"] = address

print("Processing has come to an end")
# Out:
# Currently processing sample 0...
# Processing has come to an end

# %%
#since all the properties in the site are from Dhaka
df["city"]="Dhaka"
df.head(3).T
# Out:
#                                                                             0  \
# address                                                            Bangladesh
# num_bath_rooms                                                              0
# num_bed_rooms                                                               0
# property_overview           It is very attractive commercial office buildi...
# price                                                                  500000
# purpose                                                                  Rent
# property_url                https://sharif.com.bd/dhaka/10361/office-space...
# area                                                                     9000
# property_description                 office space for rent in motijheel dhaka
# building_type                                                          Office
# cctv-security-amenity                                                     NaN
# ...

# %%
df.to_csv("NaveenKumarM_Cleaned_Sharif.csv", encoding='utf-8', index=False)
